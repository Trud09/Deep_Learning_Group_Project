# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root_dir = '/content/drive/MyDrive/Models_exp2.12'

# %%
import os
import multiprocessing
import numpy as np
import cv2
import time
import shutil

import torch

import keras
from tensorflow.keras.applications import EfficientNetB0

# %%
# !nvidia-smi
# Out:
# Fri Apr 30 20:41:28 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    23W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#https://keras.io/examples/vision/image_classification_efficientnet_fine_tuning/
#efficient nets are a lot easier to work with in keras
from keras import layers

def build_model(num_classes, IMG_SIZE):
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))

    eff_model = EfficientNetB0(include_top=False, input_tensor=inputs, weights="imagenet")

    # Freeze the pretrained weights
    eff_model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(eff_model.output)
    x = layers.BatchNormalization()(x)

    # top_dropout_rate = 0.2
    # x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(num_classes, activation="softmax", name="pred")(x)

    # Compile
    model = keras.Model(inputs, outputs, name="EfficientNet")
    optimizer = keras.optimizers.SGD(learning_rate=0.001,momentum=.9)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )
    return model

# %%
views = ['bottom', 'side_1', 'side_2', 'side_3', 'side_4', 'top', 'top_1', 'top_2', 'top_3', 'top_4', 'bot_1', 'bot_2', 'bot_3', 'bot_4']
#np.savez_compressed('/content/drive/MyDrive/Cache/keras/train_val', x=x, y=y, x_val=val_x, y_val=val_y)
file = np.load('/content/drive/MyDrive/Cache/keras/train_val.npz')
x = file['x']
y = file['y']
x_val = file['x_val']
y_val = file['y_val']

# %%
#https://stackoverflow.com/questions/60567679/save-keras-model-weights-directly-to-bytes-memory
class Save_Best_Weights(keras.callbacks.Callback):   
  def __init__(self, min=True, metric='val_loss'):
      super(Save_Best_Weights, self).__init__()
      self.best = np.Inf
      self.metric = metric
      self.min = min
      if not min:
        self.best = self.best * - 1


  def on_epoch_end(self, epoch, logs=None):
      current_metric = logs.get(self.metric)
      if self.min:
        if np.less(current_metric, self.best):
            self.best = current_metric            
            self.best_weights = model.get_weights() 
            self.name = 'ep_' + str(epoch) + '_' + self.metric + "_" + str(self.best)
            print('saved new ' + self.metric)
      else:
        if np.greater(current_metric, self.best):
            self.best = current_metric            
            self.best_weights = model.get_weights() 
            self.name = 'ep_' + str(epoch) + '_' + self.metric + "_" + str(self.best)
            print('saved new ' + self.metric)

# %%
#https://androidkt.com/set-class-weight-for-imbalance-dataset-in-keras/

from sklearn.utils import class_weight


class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y.argmax(1)),
                                                 y.argmax(1))

class_weights = dict(enumerate(class_weights))

# %%
batch_size = 32
epochs = 100

if not os.path.exists(root_dir):
    os.makedirs(root_dir)


for idx, view in enumerate(views):
    this_dir = os.path.join(root_dir, str(idx) + '_' + view)
    if not os.path.exists(this_dir):
      os.makedirs(this_dir)
    model = build_model(10, 224)
    print(view)
    loss_cp = Save_Best_Weights(
    )

    acc_cp = Save_Best_Weights(
        metric="val_accuracy",
        min=False
    )

    logger = keras.callbacks.CSVLogger(os.path.join(this_dir, 'logs.csv'))
      
    
    batch_x = x[:, idx, ...]
    batch_x_val = x_val[:, idx, ...]

    model.fit(batch_x, y, batch_size, epochs, callbacks=[loss_cp, acc_cp, logger], validation_data=(batch_x_val, y_val), class_weight=class_weights)


    #loss saving
    model.set_weights(loss_cp.best_weights)
    model.save(os.path.join(this_dir, loss_cp.name))

    #acc saving
    model.set_weights(acc_cp.best_weights)
    model.save(os.path.join(this_dir, acc_cp.name))
          

      

print('Finished Training')
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 1s 0us/step
# bottom
# Epoch 1/100
# 113/113 [==============================] - 27s 43ms/step - loss: 1.9333 - accuracy: 0.3729 - val_loss: 1.1677 - val_accuracy: 0.7100
# saved new val_loss
# saved new val_accuracy
# Epoch 2/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.7820 - accuracy: 0.7437 - val_loss: 0.7949 - val_accuracy: 0.7825
# saved new val_loss
# saved new val_accuracy
# Epoch 3/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.6576 - accuracy: 0.7982 - val_loss: 0.6333 - val_accuracy: 0.8125
# saved new val_loss
# saved new val_accuracy
# Epoch 4/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.6118 - accuracy: 0.8084 - val_loss: 0.5885 - val_accuracy: 0.8275
# saved new val_loss
# saved new val_accuracy
# Epoch 5/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.5294 - accuracy: 0.8214 - val_loss: 0.5462 - val_accuracy: 0.8350
# saved new val_loss
# saved new val_accuracy
# Epoch 6/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.4700 - accuracy: 0.8493 - val_loss: 0.5465 - val_accuracy: 0.8175
# Epoch 7/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.4467 - accuracy: 0.8552 - val_loss: 0.5145 - val_accuracy: 0.8250
# saved new val_loss
# Epoch 8/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.4710 - accuracy: 0.8517 - val_loss: 0.5161 - val_accuracy: 0.8225
# Epoch 9/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.4223 - accuracy: 0.8671 - val_loss: 0.5213 - val_accuracy: 0.8250
# Epoch 10/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.4049 - accuracy: 0.8682 - val_loss: 0.5038 - val_accuracy: 0.8250
# saved new val_loss
# Epoch 11/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3964 - accuracy: 0.8650 - val_loss: 0.5166 - val_accuracy: 0.8225
# Epoch 12/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3993 - accuracy: 0.8671 - val_loss: 0.4949 - val_accuracy: 0.8375
# saved new val_loss
# saved new val_accuracy
# Epoch 13/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3639 - accuracy: 0.8822 - val_loss: 0.5119 - val_accuracy: 0.8300
# Epoch 14/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3723 - accuracy: 0.8770 - val_loss: 0.5157 - val_accuracy: 0.8300
# Epoch 15/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3383 - accuracy: 0.8872 - val_loss: 0.4932 - val_accuracy: 0.8375
# saved new val_loss
# Epoch 16/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3502 - accuracy: 0.8806 - val_loss: 0.4885 - val_accuracy: 0.8425
# saved new val_loss
# saved new val_accuracy
# Epoch 17/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3501 - accuracy: 0.8918 - val_loss: 0.4948 - val_accuracy: 0.8375
# Epoch 18/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3609 - accuracy: 0.8844 - val_loss: 0.4875 - val_accuracy: 0.8300
# saved new val_loss
# Epoch 19/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3114 - accuracy: 0.8946 - val_loss: 0.4863 - val_accuracy: 0.8475
# saved new val_loss
# saved new val_accuracy
# Epoch 20/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3039 - accuracy: 0.8966 - val_loss: 0.4825 - val_accuracy: 0.8550
# saved new val_loss
# saved new val_accuracy
# Epoch 21/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3268 - accuracy: 0.8910 - val_loss: 0.4840 - val_accuracy: 0.8575
# saved new val_accuracy
# Epoch 22/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3014 - accuracy: 0.9031 - val_loss: 0.4895 - val_accuracy: 0.8475
# Epoch 23/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3055 - accuracy: 0.8899 - val_loss: 0.4862 - val_accuracy: 0.8525
# Epoch 24/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2819 - accuracy: 0.9065 - val_loss: 0.4916 - val_accuracy: 0.8550
# Epoch 25/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2974 - accuracy: 0.9053 - val_loss: 0.4817 - val_accuracy: 0.8500
# saved new val_loss
# Epoch 26/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2942 - accuracy: 0.9055 - val_loss: 0.4761 - val_accuracy: 0.8475
# saved new val_loss
# Epoch 27/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2792 - accuracy: 0.9043 - val_loss: 0.4849 - val_accuracy: 0.8400
# Epoch 28/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2949 - accuracy: 0.9062 - val_loss: 0.4801 - val_accuracy: 0.8650
# saved new val_accuracy
# Epoch 29/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2805 - accuracy: 0.9176 - val_loss: 0.4809 - val_accuracy: 0.8525
# Epoch 30/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2678 - accuracy: 0.9147 - val_loss: 0.4758 - val_accuracy: 0.8475
# saved new val_loss
# Epoch 31/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2669 - accuracy: 0.9114 - val_loss: 0.4848 - val_accuracy: 0.8525
# Epoch 32/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2663 - accuracy: 0.9119 - val_loss: 0.4785 - val_accuracy: 0.8500
# Epoch 33/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2741 - accuracy: 0.9115 - val_loss: 0.4785 - val_accuracy: 0.8525
# Epoch 34/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2449 - accuracy: 0.9183 - val_loss: 0.4825 - val_accuracy: 0.8525
# Epoch 35/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2567 - accuracy: 0.9171 - val_loss: 0.4707 - val_accuracy: 0.8575
# saved new val_loss
# Epoch 36/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2365 - accuracy: 0.9244 - val_loss: 0.4774 - val_accuracy: 0.8650
# Epoch 37/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2578 - accuracy: 0.9215 - val_loss: 0.4796 - val_accuracy: 0.8525
# Epoch 38/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2641 - accuracy: 0.9129 - val_loss: 0.4771 - val_accuracy: 0.8525
# Epoch 39/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2465 - accuracy: 0.9182 - val_loss: 0.4753 - val_accuracy: 0.8475
# Epoch 40/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2426 - accuracy: 0.9251 - val_loss: 0.4818 - val_accuracy: 0.8550
# Epoch 41/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2336 - accuracy: 0.9320 - val_loss: 0.4775 - val_accuracy: 0.8550
# Epoch 42/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2255 - accuracy: 0.9331 - val_loss: 0.4727 - val_accuracy: 0.8525
# Epoch 43/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2441 - accuracy: 0.9132 - val_loss: 0.4800 - val_accuracy: 0.8450
# Epoch 44/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2252 - accuracy: 0.9221 - val_loss: 0.4787 - val_accuracy: 0.8550
# Epoch 45/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2286 - accuracy: 0.9206 - val_loss: 0.4809 - val_accuracy: 0.8625
# Epoch 46/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2447 - accuracy: 0.9230 - val_loss: 0.4754 - val_accuracy: 0.8575
# Epoch 47/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2382 - accuracy: 0.9272 - val_loss: 0.4754 - val_accuracy: 0.8625
# Epoch 48/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2175 - accuracy: 0.9307 - val_loss: 0.4867 - val_accuracy: 0.8550
# Epoch 49/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2304 - accuracy: 0.9306 - val_loss: 0.4902 - val_accuracy: 0.8525
# Epoch 50/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2293 - accuracy: 0.9260 - val_loss: 0.4833 - val_accuracy: 0.8575
# Epoch 51/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2169 - accuracy: 0.9349 - val_loss: 0.4761 - val_accuracy: 0.8550
# Epoch 52/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2269 - accuracy: 0.9334 - val_loss: 0.4769 - val_accuracy: 0.8525
# Epoch 53/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1982 - accuracy: 0.9340 - val_loss: 0.4774 - val_accuracy: 0.8550
# Epoch 54/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2168 - accuracy: 0.9290 - val_loss: 0.4807 - val_accuracy: 0.8550
# Epoch 55/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2112 - accuracy: 0.9365 - val_loss: 0.4868 - val_accuracy: 0.8600
# Epoch 56/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2222 - accuracy: 0.9242 - val_loss: 0.4792 - val_accuracy: 0.8600
# Epoch 57/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2242 - accuracy: 0.9237 - val_loss: 0.4797 - val_accuracy: 0.8550
# Epoch 58/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2176 - accuracy: 0.9290 - val_loss: 0.4775 - val_accuracy: 0.8525
# Epoch 59/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2111 - accuracy: 0.9365 - val_loss: 0.4813 - val_accuracy: 0.8600
# Epoch 60/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1993 - accuracy: 0.9311 - val_loss: 0.4740 - val_accuracy: 0.8525
# Epoch 61/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2034 - accuracy: 0.9301 - val_loss: 0.4750 - val_accuracy: 0.8550
# Epoch 62/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2022 - accuracy: 0.9358 - val_loss: 0.4768 - val_accuracy: 0.8500
# Epoch 63/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1806 - accuracy: 0.9431 - val_loss: 0.4811 - val_accuracy: 0.8600
# Epoch 64/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2027 - accuracy: 0.9345 - val_loss: 0.4742 - val_accuracy: 0.8625
# Epoch 65/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1901 - accuracy: 0.9350 - val_loss: 0.4791 - val_accuracy: 0.8500
# Epoch 66/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2026 - accuracy: 0.9309 - val_loss: 0.4802 - val_accuracy: 0.8575
# Epoch 67/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2094 - accuracy: 0.9355 - val_loss: 0.4807 - val_accuracy: 0.8625
# Epoch 68/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1947 - accuracy: 0.9360 - val_loss: 0.4808 - val_accuracy: 0.8550
# Epoch 69/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1957 - accuracy: 0.9412 - val_loss: 0.4876 - val_accuracy: 0.8600
# Epoch 70/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1826 - accuracy: 0.9383 - val_loss: 0.4827 - val_accuracy: 0.8600
# Epoch 71/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1869 - accuracy: 0.9377 - val_loss: 0.4862 - val_accuracy: 0.8575
# Epoch 72/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1967 - accuracy: 0.9355 - val_loss: 0.4818 - val_accuracy: 0.8575
# Epoch 73/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1790 - accuracy: 0.9400 - val_loss: 0.4753 - val_accuracy: 0.8625
# Epoch 74/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1833 - accuracy: 0.9439 - val_loss: 0.4849 - val_accuracy: 0.8575
# Epoch 75/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2057 - accuracy: 0.9241 - val_loss: 0.4792 - val_accuracy: 0.8725
# saved new val_accuracy
# Epoch 76/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1904 - accuracy: 0.9376 - val_loss: 0.4756 - val_accuracy: 0.8625
# Epoch 77/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2035 - accuracy: 0.9301 - val_loss: 0.4832 - val_accuracy: 0.8525
# Epoch 78/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1863 - accuracy: 0.9396 - val_loss: 0.4841 - val_accuracy: 0.8550
# Epoch 79/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1696 - accuracy: 0.9490 - val_loss: 0.4795 - val_accuracy: 0.8550
# Epoch 80/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1868 - accuracy: 0.9438 - val_loss: 0.4754 - val_accuracy: 0.8650
# Epoch 81/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1898 - accuracy: 0.9415 - val_loss: 0.4822 - val_accuracy: 0.8625
# Epoch 82/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1764 - accuracy: 0.9438 - val_loss: 0.4821 - val_accuracy: 0.8625
# Epoch 83/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1700 - accuracy: 0.9434 - val_loss: 0.4787 - val_accuracy: 0.8650
# Epoch 84/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1785 - accuracy: 0.9465 - val_loss: 0.4808 - val_accuracy: 0.8675
# Epoch 85/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1672 - accuracy: 0.9453 - val_loss: 0.4864 - val_accuracy: 0.8650
# Epoch 86/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1750 - accuracy: 0.9402 - val_loss: 0.4815 - val_accuracy: 0.8700
# Epoch 87/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1741 - accuracy: 0.9449 - val_loss: 0.4809 - val_accuracy: 0.8700
# Epoch 88/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1654 - accuracy: 0.9394 - val_loss: 0.4794 - val_accuracy: 0.8600
# Epoch 89/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1580 - accuracy: 0.9478 - val_loss: 0.4892 - val_accuracy: 0.8600
# Epoch 90/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1764 - accuracy: 0.9463 - val_loss: 0.4827 - val_accuracy: 0.8600
# Epoch 91/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1689 - accuracy: 0.9449 - val_loss: 0.4799 - val_accuracy: 0.8675
# Epoch 92/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1595 - accuracy: 0.9461 - val_loss: 0.4738 - val_accuracy: 0.8650
# Epoch 93/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1765 - accuracy: 0.9452 - val_loss: 0.4756 - val_accuracy: 0.8625
# Epoch 94/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1538 - accuracy: 0.9523 - val_loss: 0.4854 - val_accuracy: 0.8675
# Epoch 95/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1670 - accuracy: 0.9470 - val_loss: 0.4858 - val_accuracy: 0.8775
# saved new val_accuracy
# Epoch 96/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1478 - accuracy: 0.9519 - val_loss: 0.4859 - val_accuracy: 0.8725
# Epoch 97/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1763 - accuracy: 0.9402 - val_loss: 0.4832 - val_accuracy: 0.8700
# Epoch 98/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1769 - accuracy: 0.9401 - val_loss: 0.4904 - val_accuracy: 0.8600
# Epoch 99/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1544 - accuracy: 0.9435 - val_loss: 0.4875 - val_accuracy: 0.8600
# Epoch 100/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1819 - accuracy: 0.9374 - val_loss: 0.4796 - val_accuracy: 0.8675
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.12/0_bottom/ep_34_val_loss_0.4707190692424774/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.12/0_bottom/ep_94_val_accuracy_0.8774999976158142/assets
# side_1
# Epoch 1/100
# 113/113 [==============================] - 11s 39ms/step - loss: 1.6940 - accuracy: 0.4727 - val_loss: 0.8538 - val_accuracy: 0.8350
# saved new val_loss
# saved new val_accuracy
# Epoch 2/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.6363 - accuracy: 0.8137 - val_loss: 0.5360 - val_accuracy: 0.8600
# saved new val_loss
# saved new val_accuracy
# Epoch 3/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.5299 - accuracy: 0.8507 - val_loss: 0.4094 - val_accuracy: 0.8850
# saved new val_loss
# saved new val_accuracy
# Epoch 4/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.4539 - accuracy: 0.8693 - val_loss: 0.3641 - val_accuracy: 0.8900
# saved new val_loss
# saved new val_accuracy
# Epoch 5/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3842 - accuracy: 0.8908 - val_loss: 0.3340 - val_accuracy: 0.9025
# saved new val_loss
# saved new val_accuracy
# Epoch 6/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3679 - accuracy: 0.8958 - val_loss: 0.3271 - val_accuracy: 0.8950
# saved new val_loss
# Epoch 7/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3161 - accuracy: 0.9062 - val_loss: 0.3136 - val_accuracy: 0.8925
# saved new val_loss
# Epoch 8/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2983 - accuracy: 0.9118 - val_loss: 0.3137 - val_accuracy: 0.8975
# Epoch 9/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3109 - accuracy: 0.9172 - val_loss: 0.3058 - val_accuracy: 0.9025
# saved new val_loss
# Epoch 10/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2961 - accuracy: 0.9129 - val_loss: 0.3000 - val_accuracy: 0.9075
# saved new val_loss
# saved new val_accuracy
# Epoch 11/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2857 - accuracy: 0.9171 - val_loss: 0.3007 - val_accuracy: 0.8925
# Epoch 12/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2677 - accuracy: 0.9260 - val_loss: 0.2971 - val_accuracy: 0.9025
# saved new val_loss
# Epoch 13/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2597 - accuracy: 0.9323 - val_loss: 0.2906 - val_accuracy: 0.9100
# saved new val_loss
# saved new val_accuracy
# Epoch 14/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2607 - accuracy: 0.9290 - val_loss: 0.2833 - val_accuracy: 0.9150
# saved new val_loss
# saved new val_accuracy
# Epoch 15/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2668 - accuracy: 0.9222 - val_loss: 0.2879 - val_accuracy: 0.9100
# Epoch 16/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2198 - accuracy: 0.9441 - val_loss: 0.2852 - val_accuracy: 0.9125
# Epoch 17/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2405 - accuracy: 0.9276 - val_loss: 0.2902 - val_accuracy: 0.9075
# Epoch 18/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2368 - accuracy: 0.9362 - val_loss: 0.2879 - val_accuracy: 0.9125
# Epoch 19/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2234 - accuracy: 0.9281 - val_loss: 0.2912 - val_accuracy: 0.9150
# Epoch 20/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1964 - accuracy: 0.9498 - val_loss: 0.2856 - val_accuracy: 0.9150
# Epoch 21/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2099 - accuracy: 0.9454 - val_loss: 0.2883 - val_accuracy: 0.9000
# Epoch 22/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1933 - accuracy: 0.9474 - val_loss: 0.2852 - val_accuracy: 0.9100
# Epoch 23/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1991 - accuracy: 0.9461 - val_loss: 0.2805 - val_accuracy: 0.9100
# saved new val_loss
# Epoch 24/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2045 - accuracy: 0.9431 - val_loss: 0.2792 - val_accuracy: 0.9150
# saved new val_loss
# Epoch 25/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1932 - accuracy: 0.9493 - val_loss: 0.2772 - val_accuracy: 0.9125
# saved new val_loss
# Epoch 26/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1830 - accuracy: 0.9512 - val_loss: 0.2751 - val_accuracy: 0.9175
# saved new val_loss
# saved new val_accuracy
# Epoch 27/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1613 - accuracy: 0.9622 - val_loss: 0.2765 - val_accuracy: 0.9200
# saved new val_accuracy
# Epoch 28/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1835 - accuracy: 0.9396 - val_loss: 0.2738 - val_accuracy: 0.9200
# saved new val_loss
# Epoch 29/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1804 - accuracy: 0.9462 - val_loss: 0.2760 - val_accuracy: 0.9175
# Epoch 30/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1630 - accuracy: 0.9600 - val_loss: 0.2707 - val_accuracy: 0.9175
# saved new val_loss
# Epoch 31/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1866 - accuracy: 0.9456 - val_loss: 0.2737 - val_accuracy: 0.9150
# Epoch 32/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1587 - accuracy: 0.9623 - val_loss: 0.2745 - val_accuracy: 0.9200
# Epoch 33/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1834 - accuracy: 0.9514 - val_loss: 0.2739 - val_accuracy: 0.9125
# Epoch 34/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1601 - accuracy: 0.9547 - val_loss: 0.2789 - val_accuracy: 0.9150
# Epoch 35/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1732 - accuracy: 0.9482 - val_loss: 0.2811 - val_accuracy: 0.9125
# Epoch 36/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1601 - accuracy: 0.9533 - val_loss: 0.2739 - val_accuracy: 0.9175
# Epoch 37/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1762 - accuracy: 0.9525 - val_loss: 0.2715 - val_accuracy: 0.9150
# Epoch 38/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1510 - accuracy: 0.9552 - val_loss: 0.2693 - val_accuracy: 0.9175
# saved new val_loss
# Epoch 39/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1543 - accuracy: 0.9558 - val_loss: 0.2690 - val_accuracy: 0.9200
# saved new val_loss
# Epoch 40/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1518 - accuracy: 0.9632 - val_loss: 0.2717 - val_accuracy: 0.9200
# Epoch 41/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1642 - accuracy: 0.9520 - val_loss: 0.2749 - val_accuracy: 0.9200
# Epoch 42/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1488 - accuracy: 0.9577 - val_loss: 0.2673 - val_accuracy: 0.9125
# saved new val_loss
# Epoch 43/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1455 - accuracy: 0.9573 - val_loss: 0.2688 - val_accuracy: 0.9150
# Epoch 44/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1471 - accuracy: 0.9596 - val_loss: 0.2786 - val_accuracy: 0.9175
# Epoch 45/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1426 - accuracy: 0.9598 - val_loss: 0.2740 - val_accuracy: 0.9125
# Epoch 46/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1370 - accuracy: 0.9612 - val_loss: 0.2737 - val_accuracy: 0.9200
# Epoch 47/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1379 - accuracy: 0.9639 - val_loss: 0.2744 - val_accuracy: 0.9125
# Epoch 48/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1452 - accuracy: 0.9606 - val_loss: 0.2803 - val_accuracy: 0.9050
# Epoch 49/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1220 - accuracy: 0.9691 - val_loss: 0.2741 - val_accuracy: 0.9125
# Epoch 50/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1471 - accuracy: 0.9599 - val_loss: 0.2775 - val_accuracy: 0.9225
# saved new val_accuracy
# Epoch 51/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1182 - accuracy: 0.9736 - val_loss: 0.2785 - val_accuracy: 0.9200
# Epoch 52/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1408 - accuracy: 0.9625 - val_loss: 0.2736 - val_accuracy: 0.9175
# Epoch 53/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1127 - accuracy: 0.9710 - val_loss: 0.2752 - val_accuracy: 0.9200
# Epoch 54/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1244 - accuracy: 0.9667 - val_loss: 0.2795 - val_accuracy: 0.9200
# Epoch 55/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1187 - accuracy: 0.9682 - val_loss: 0.2811 - val_accuracy: 0.9100
# Epoch 56/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1277 - accuracy: 0.9679 - val_loss: 0.2781 - val_accuracy: 0.9150
# Epoch 57/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1277 - accuracy: 0.9656 - val_loss: 0.2770 - val_accuracy: 0.9125
# Epoch 58/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1337 - accuracy: 0.9659 - val_loss: 0.2744 - val_accuracy: 0.9125
# Epoch 59/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1255 - accuracy: 0.9675 - val_loss: 0.2760 - val_accuracy: 0.9150
# Epoch 60/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1281 - accuracy: 0.9670 - val_loss: 0.2803 - val_accuracy: 0.9175
# Epoch 61/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1286 - accuracy: 0.9684 - val_loss: 0.2712 - val_accuracy: 0.9175
# Epoch 62/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1138 - accuracy: 0.9686 - val_loss: 0.2720 - val_accuracy: 0.9225
# Epoch 63/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1157 - accuracy: 0.9677 - val_loss: 0.2739 - val_accuracy: 0.9200
# Epoch 64/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1130 - accuracy: 0.9719 - val_loss: 0.2786 - val_accuracy: 0.9200
# Epoch 65/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1143 - accuracy: 0.9745 - val_loss: 0.2788 - val_accuracy: 0.9200
# Epoch 66/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1084 - accuracy: 0.9700 - val_loss: 0.2797 - val_accuracy: 0.9175
# Epoch 67/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1108 - accuracy: 0.9742 - val_loss: 0.2745 - val_accuracy: 0.9275
# saved new val_accuracy
# Epoch 68/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1178 - accuracy: 0.9709 - val_loss: 0.2765 - val_accuracy: 0.9200
# Epoch 69/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1076 - accuracy: 0.9701 - val_loss: 0.2777 - val_accuracy: 0.9200
# Epoch 70/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1286 - accuracy: 0.9684 - val_loss: 0.2774 - val_accuracy: 0.9125
# Epoch 71/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1056 - accuracy: 0.9730 - val_loss: 0.2809 - val_accuracy: 0.9200
# Epoch 72/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0971 - accuracy: 0.9754 - val_loss: 0.2829 - val_accuracy: 0.9200
# Epoch 73/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1141 - accuracy: 0.9719 - val_loss: 0.2819 - val_accuracy: 0.9225
# Epoch 74/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1170 - accuracy: 0.9683 - val_loss: 0.2769 - val_accuracy: 0.9150
# Epoch 75/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1115 - accuracy: 0.9734 - val_loss: 0.2790 - val_accuracy: 0.9200
# Epoch 76/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0956 - accuracy: 0.9766 - val_loss: 0.2732 - val_accuracy: 0.9175
# Epoch 77/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1045 - accuracy: 0.9753 - val_loss: 0.2762 - val_accuracy: 0.9200
# Epoch 78/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0897 - accuracy: 0.9786 - val_loss: 0.2787 - val_accuracy: 0.9175
# Epoch 79/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1030 - accuracy: 0.9719 - val_loss: 0.2779 - val_accuracy: 0.9200
# Epoch 80/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1107 - accuracy: 0.9690 - val_loss: 0.2807 - val_accuracy: 0.9150
# Epoch 81/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1253 - accuracy: 0.9655 - val_loss: 0.2795 - val_accuracy: 0.9175
# Epoch 82/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0891 - accuracy: 0.9753 - val_loss: 0.2825 - val_accuracy: 0.9125
# Epoch 83/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1003 - accuracy: 0.9756 - val_loss: 0.2833 - val_accuracy: 0.9150
# Epoch 84/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1086 - accuracy: 0.9737 - val_loss: 0.2899 - val_accuracy: 0.9175
# Epoch 85/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0938 - accuracy: 0.9703 - val_loss: 0.2867 - val_accuracy: 0.9200
# Epoch 86/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0966 - accuracy: 0.9742 - val_loss: 0.2864 - val_accuracy: 0.9100
# Epoch 87/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0954 - accuracy: 0.9768 - val_loss: 0.2882 - val_accuracy: 0.9100
# Epoch 88/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1013 - accuracy: 0.9770 - val_loss: 0.2857 - val_accuracy: 0.9100
# Epoch 89/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1042 - accuracy: 0.9716 - val_loss: 0.2808 - val_accuracy: 0.9175
# Epoch 90/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1025 - accuracy: 0.9716 - val_loss: 0.2864 - val_accuracy: 0.9050
# Epoch 91/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1006 - accuracy: 0.9749 - val_loss: 0.2900 - val_accuracy: 0.9125
# Epoch 92/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0936 - accuracy: 0.9783 - val_loss: 0.2867 - val_accuracy: 0.9100
# Epoch 93/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1064 - accuracy: 0.9709 - val_loss: 0.2859 - val_accuracy: 0.9150
# Epoch 94/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0965 - accuracy: 0.9763 - val_loss: 0.2857 - val_accuracy: 0.9100
# Epoch 95/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0916 - accuracy: 0.9745 - val_loss: 0.2820 - val_accuracy: 0.9150
# Epoch 96/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0965 - accuracy: 0.9783 - val_loss: 0.2829 - val_accuracy: 0.9125
# Epoch 97/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0871 - accuracy: 0.9743 - val_loss: 0.2838 - val_accuracy: 0.9125
# Epoch 98/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0871 - accuracy: 0.9791 - val_loss: 0.2871 - val_accuracy: 0.9125
# Epoch 99/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0897 - accuracy: 0.9767 - val_loss: 0.2874 - val_accuracy: 0.9125
# Epoch 100/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1005 - accuracy: 0.9736 - val_loss: 0.2883 - val_accuracy: 0.9150
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.12/1_side_1/ep_41_val_loss_0.2673448622226715/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.12/1_side_1/ep_66_val_accuracy_0.9275000095367432/assets
# side_2
# Epoch 1/100
# 113/113 [==============================] - 11s 38ms/step - loss: 1.7649 - accuracy: 0.4431 - val_loss: 0.8853 - val_accuracy: 0.8100
# saved new val_loss
# saved new val_accuracy
# Epoch 2/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.5535 - accuracy: 0.8344 - val_loss: 0.5215 - val_accuracy: 0.8750
# saved new val_loss
# saved new val_accuracy
# Epoch 3/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.4771 - accuracy: 0.8722 - val_loss: 0.3905 - val_accuracy: 0.8850
# saved new val_loss
# saved new val_accuracy
# Epoch 4/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.4224 - accuracy: 0.8819 - val_loss: 0.3515 - val_accuracy: 0.8825
# saved new val_loss
# Epoch 5/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3745 - accuracy: 0.8951 - val_loss: 0.3163 - val_accuracy: 0.8975
# saved new val_loss
# saved new val_accuracy
# Epoch 6/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3363 - accuracy: 0.9043 - val_loss: 0.3175 - val_accuracy: 0.8950
# Epoch 7/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3346 - accuracy: 0.9133 - val_loss: 0.2981 - val_accuracy: 0.8950
# saved new val_loss
# Epoch 8/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3048 - accuracy: 0.9142 - val_loss: 0.2825 - val_accuracy: 0.9000
# saved new val_loss
# saved new val_accuracy
# Epoch 9/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2960 - accuracy: 0.9197 - val_loss: 0.2777 - val_accuracy: 0.9050
# saved new val_loss
# saved new val_accuracy
# Epoch 10/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.2630 - accuracy: 0.9292 - val_loss: 0.2719 - val_accuracy: 0.9125
# saved new val_loss
# saved new val_accuracy
# Epoch 11/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2513 - accuracy: 0.9312 - val_loss: 0.2665 - val_accuracy: 0.9150
# saved new val_loss
# saved new val_accuracy
# Epoch 12/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2484 - accuracy: 0.9325 - val_loss: 0.2694 - val_accuracy: 0.9150
# Epoch 13/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2225 - accuracy: 0.9414 - val_loss: 0.2723 - val_accuracy: 0.9000
# Epoch 14/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2347 - accuracy: 0.9322 - val_loss: 0.2584 - val_accuracy: 0.9125
# saved new val_loss
# Epoch 15/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1971 - accuracy: 0.9533 - val_loss: 0.2610 - val_accuracy: 0.9075
# Epoch 16/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1864 - accuracy: 0.9468 - val_loss: 0.2590 - val_accuracy: 0.9125
# Epoch 17/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2008 - accuracy: 0.9467 - val_loss: 0.2604 - val_accuracy: 0.9050
# Epoch 18/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2044 - accuracy: 0.9378 - val_loss: 0.2557 - val_accuracy: 0.9025
# saved new val_loss
# Epoch 19/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1813 - accuracy: 0.9495 - val_loss: 0.2581 - val_accuracy: 0.9025
# Epoch 20/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2045 - accuracy: 0.9458 - val_loss: 0.2512 - val_accuracy: 0.9050
# saved new val_loss
# Epoch 21/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1719 - accuracy: 0.9560 - val_loss: 0.2447 - val_accuracy: 0.9125
# saved new val_loss
# Epoch 22/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1879 - accuracy: 0.9486 - val_loss: 0.2418 - val_accuracy: 0.9150
# saved new val_loss
# Epoch 23/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1728 - accuracy: 0.9476 - val_loss: 0.2439 - val_accuracy: 0.9075
# Epoch 24/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1778 - accuracy: 0.9546 - val_loss: 0.2447 - val_accuracy: 0.9100
# Epoch 25/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1724 - accuracy: 0.9534 - val_loss: 0.2543 - val_accuracy: 0.9050
# Epoch 26/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1647 - accuracy: 0.9541 - val_loss: 0.2465 - val_accuracy: 0.9050
# Epoch 27/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1697 - accuracy: 0.9549 - val_loss: 0.2475 - val_accuracy: 0.9000
# Epoch 28/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1625 - accuracy: 0.9548 - val_loss: 0.2450 - val_accuracy: 0.9025
# Epoch 29/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1529 - accuracy: 0.9602 - val_loss: 0.2445 - val_accuracy: 0.9050
# Epoch 30/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1614 - accuracy: 0.9547 - val_loss: 0.2480 - val_accuracy: 0.9075
# Epoch 31/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1433 - accuracy: 0.9639 - val_loss: 0.2458 - val_accuracy: 0.9050
# Epoch 32/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1379 - accuracy: 0.9652 - val_loss: 0.2468 - val_accuracy: 0.9075
# Epoch 33/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1450 - accuracy: 0.9608 - val_loss: 0.2473 - val_accuracy: 0.9025
# Epoch 34/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1623 - accuracy: 0.9507 - val_loss: 0.2494 - val_accuracy: 0.9125
# Epoch 35/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1470 - accuracy: 0.9670 - val_loss: 0.2489 - val_accuracy: 0.9025
# Epoch 36/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1503 - accuracy: 0.9571 - val_loss: 0.2420 - val_accuracy: 0.9100
# Epoch 37/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1466 - accuracy: 0.9620 - val_loss: 0.2399 - val_accuracy: 0.9100
# saved new val_loss
# Epoch 38/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1469 - accuracy: 0.9622 - val_loss: 0.2400 - val_accuracy: 0.9050
# Epoch 39/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1332 - accuracy: 0.9616 - val_loss: 0.2462 - val_accuracy: 0.9200
# saved new val_accuracy
# Epoch 40/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1310 - accuracy: 0.9688 - val_loss: 0.2387 - val_accuracy: 0.9150
# saved new val_loss
# Epoch 41/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1242 - accuracy: 0.9710 - val_loss: 0.2335 - val_accuracy: 0.9150
# saved new val_loss
# Epoch 42/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1234 - accuracy: 0.9689 - val_loss: 0.2331 - val_accuracy: 0.9150
# saved new val_loss
# Epoch 43/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1185 - accuracy: 0.9694 - val_loss: 0.2390 - val_accuracy: 0.9175
# Epoch 44/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1331 - accuracy: 0.9671 - val_loss: 0.2352 - val_accuracy: 0.9175
# Epoch 45/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1245 - accuracy: 0.9642 - val_loss: 0.2353 - val_accuracy: 0.9200
# Epoch 46/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1226 - accuracy: 0.9707 - val_loss: 0.2358 - val_accuracy: 0.9100
# Epoch 47/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1220 - accuracy: 0.9669 - val_loss: 0.2379 - val_accuracy: 0.9250
# saved new val_accuracy
# Epoch 48/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1200 - accuracy: 0.9685 - val_loss: 0.2376 - val_accuracy: 0.9125
# Epoch 49/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1164 - accuracy: 0.9681 - val_loss: 0.2417 - val_accuracy: 0.9075
# Epoch 50/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1202 - accuracy: 0.9690 - val_loss: 0.2384 - val_accuracy: 0.9075
# Epoch 51/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1334 - accuracy: 0.9641 - val_loss: 0.2397 - val_accuracy: 0.9150
# Epoch 52/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1216 - accuracy: 0.9691 - val_loss: 0.2429 - val_accuracy: 0.9100
# Epoch 53/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1179 - accuracy: 0.9712 - val_loss: 0.2483 - val_accuracy: 0.9125
# Epoch 54/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1181 - accuracy: 0.9712 - val_loss: 0.2484 - val_accuracy: 0.9100
# Epoch 55/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1166 - accuracy: 0.9741 - val_loss: 0.2374 - val_accuracy: 0.9100
# Epoch 56/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1101 - accuracy: 0.9765 - val_loss: 0.2396 - val_accuracy: 0.9175
# Epoch 57/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1294 - accuracy: 0.9723 - val_loss: 0.2443 - val_accuracy: 0.9175
# Epoch 58/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1029 - accuracy: 0.9723 - val_loss: 0.2381 - val_accuracy: 0.9125
# Epoch 59/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0987 - accuracy: 0.9788 - val_loss: 0.2389 - val_accuracy: 0.9150
# Epoch 60/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1074 - accuracy: 0.9725 - val_loss: 0.2373 - val_accuracy: 0.9175
# Epoch 61/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1041 - accuracy: 0.9711 - val_loss: 0.2450 - val_accuracy: 0.9175
# Epoch 62/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1090 - accuracy: 0.9732 - val_loss: 0.2403 - val_accuracy: 0.9125
# Epoch 63/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1161 - accuracy: 0.9706 - val_loss: 0.2409 - val_accuracy: 0.9125
# Epoch 64/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1016 - accuracy: 0.9763 - val_loss: 0.2474 - val_accuracy: 0.9125
# Epoch 65/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1089 - accuracy: 0.9731 - val_loss: 0.2455 - val_accuracy: 0.9100
# Epoch 66/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1097 - accuracy: 0.9724 - val_loss: 0.2438 - val_accuracy: 0.9175
# Epoch 67/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1018 - accuracy: 0.9756 - val_loss: 0.2469 - val_accuracy: 0.9175
# Epoch 68/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0861 - accuracy: 0.9799 - val_loss: 0.2481 - val_accuracy: 0.9125
# Epoch 69/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1001 - accuracy: 0.9754 - val_loss: 0.2361 - val_accuracy: 0.9150
# Epoch 70/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0879 - accuracy: 0.9782 - val_loss: 0.2481 - val_accuracy: 0.9175
# Epoch 71/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0875 - accuracy: 0.9787 - val_loss: 0.2473 - val_accuracy: 0.9150
# Epoch 72/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0956 - accuracy: 0.9788 - val_loss: 0.2450 - val_accuracy: 0.9125
# Epoch 73/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1070 - accuracy: 0.9767 - val_loss: 0.2460 - val_accuracy: 0.9150
# Epoch 74/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1054 - accuracy: 0.9743 - val_loss: 0.2430 - val_accuracy: 0.9150
# Epoch 75/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0840 - accuracy: 0.9794 - val_loss: 0.2431 - val_accuracy: 0.9175
# Epoch 76/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0906 - accuracy: 0.9778 - val_loss: 0.2416 - val_accuracy: 0.9175
# Epoch 77/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0862 - accuracy: 0.9790 - val_loss: 0.2428 - val_accuracy: 0.9200
# Epoch 78/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1161 - accuracy: 0.9687 - val_loss: 0.2439 - val_accuracy: 0.9150
# Epoch 79/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0757 - accuracy: 0.9827 - val_loss: 0.2466 - val_accuracy: 0.9200
# Epoch 80/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0927 - accuracy: 0.9682 - val_loss: 0.2473 - val_accuracy: 0.9200
# Epoch 81/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0837 - accuracy: 0.9786 - val_loss: 0.2457 - val_accuracy: 0.9175
# Epoch 82/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0798 - accuracy: 0.9793 - val_loss: 0.2435 - val_accuracy: 0.9150
# Epoch 83/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0782 - accuracy: 0.9831 - val_loss: 0.2440 - val_accuracy: 0.9175
# Epoch 84/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0854 - accuracy: 0.9804 - val_loss: 0.2439 - val_accuracy: 0.9250
# Epoch 85/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0909 - accuracy: 0.9774 - val_loss: 0.2425 - val_accuracy: 0.9200
# Epoch 86/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0864 - accuracy: 0.9794 - val_loss: 0.2474 - val_accuracy: 0.9200
# Epoch 87/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0982 - accuracy: 0.9775 - val_loss: 0.2474 - val_accuracy: 0.9250
# Epoch 88/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0719 - accuracy: 0.9840 - val_loss: 0.2429 - val_accuracy: 0.9200
# Epoch 89/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0932 - accuracy: 0.9779 - val_loss: 0.2442 - val_accuracy: 0.9225
# Epoch 90/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0837 - accuracy: 0.9791 - val_loss: 0.2472 - val_accuracy: 0.9175
# Epoch 91/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0953 - accuracy: 0.9819 - val_loss: 0.2423 - val_accuracy: 0.9175
# Epoch 92/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0787 - accuracy: 0.9798 - val_loss: 0.2386 - val_accuracy: 0.9200
# Epoch 93/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0688 - accuracy: 0.9845 - val_loss: 0.2374 - val_accuracy: 0.9225
# Epoch 94/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0852 - accuracy: 0.9766 - val_loss: 0.2453 - val_accuracy: 0.9225
# Epoch 95/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0795 - accuracy: 0.9829 - val_loss: 0.2447 - val_accuracy: 0.9225
# Epoch 96/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0852 - accuracy: 0.9790 - val_loss: 0.2409 - val_accuracy: 0.9175
# Epoch 97/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0821 - accuracy: 0.9768 - val_loss: 0.2427 - val_accuracy: 0.9175
# Epoch 98/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0859 - accuracy: 0.9771 - val_loss: 0.2431 - val_accuracy: 0.9175
# Epoch 99/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0675 - accuracy: 0.9849 - val_loss: 0.2413 - val_accuracy: 0.9150
# Epoch 100/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.0881 - accuracy: 0.9748 - val_loss: 0.2424 - val_accuracy: 0.9200
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.12/2_side_2/ep_41_val_loss_0.23307150602340698/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.12/2_side_2/ep_46_val_accuracy_0.925000011920929/assets
# side_3
# Epoch 1/100
# 113/113 [==============================] - 10s 40ms/step - loss: 1.5610 - accuracy: 0.5154 - val_loss: 0.6705 - val_accuracy: 0.8625
# saved new val_loss
# saved new val_accuracy
# Epoch 2/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.4689 - accuracy: 0.8554 - val_loss: 0.3903 - val_accuracy: 0.8900
# saved new val_loss
# saved new val_accuracy
# Epoch 3/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.3701 - accuracy: 0.8991 - val_loss: 0.2892 - val_accuracy: 0.9175
# saved new val_loss
# saved new val_accuracy
# Epoch 4/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.3122 - accuracy: 0.9093 - val_loss: 0.2457 - val_accuracy: 0.9250
# saved new val_loss
# saved new val_accuracy
# Epoch 5/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.2610 - accuracy: 0.9200 - val_loss: 0.2231 - val_accuracy: 0.9275
# saved new val_loss
# saved new val_accuracy
# Epoch 6/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.2669 - accuracy: 0.9214 - val_loss: 0.2172 - val_accuracy: 0.9250
# saved new val_loss
# Epoch 7/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2447 - accuracy: 0.9375 - val_loss: 0.2086 - val_accuracy: 0.9275
# saved new val_loss
# Epoch 8/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.2404 - accuracy: 0.9306 - val_loss: 0.2079 - val_accuracy: 0.9300
# saved new val_loss
# saved new val_accuracy
# Epoch 9/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.2231 - accuracy: 0.9345 - val_loss: 0.2030 - val_accuracy: 0.9300
# saved new val_loss
# Epoch 10/100
# ...
# Epoch 100/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0612 - accuracy: 0.9853 - val_loss: 0.3071 - val_accuracy: 0.9100
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.12/12_bot_3/ep_68_val_loss_0.29477375745773315/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.12/12_bot_3/ep_61_val_accuracy_0.9125000238418579/assets
# bot_4
# Epoch 1/100
# 113/113 [==============================] - 13s 41ms/step - loss: 1.6747 - accuracy: 0.4419 - val_loss: 0.8156 - val_accuracy: 0.8200
# saved new val_loss
# saved new val_accuracy
# Epoch 2/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.5851 - accuracy: 0.8380 - val_loss: 0.5284 - val_accuracy: 0.8525
# saved new val_loss
# saved new val_accuracy
# Epoch 3/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.4410 - accuracy: 0.8645 - val_loss: 0.4192 - val_accuracy: 0.8925
# saved new val_loss
# saved new val_accuracy
# Epoch 4/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.3815 - accuracy: 0.8875 - val_loss: 0.3627 - val_accuracy: 0.8875
# saved new val_loss
# Epoch 5/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.3231 - accuracy: 0.9039 - val_loss: 0.3438 - val_accuracy: 0.8925
# saved new val_loss
# Epoch 6/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.3254 - accuracy: 0.9028 - val_loss: 0.3338 - val_accuracy: 0.8950
# saved new val_loss
# saved new val_accuracy
# Epoch 7/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.2790 - accuracy: 0.9146 - val_loss: 0.3188 - val_accuracy: 0.8975
# saved new val_loss
# saved new val_accuracy
# Epoch 8/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.2604 - accuracy: 0.9260 - val_loss: 0.3103 - val_accuracy: 0.9100
# saved new val_loss
# saved new val_accuracy
# Epoch 9/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.2363 - accuracy: 0.9167 - val_loss: 0.3030 - val_accuracy: 0.9100
# saved new val_loss
# Epoch 10/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.2342 - accuracy: 0.9293 - val_loss: 0.3011 - val_accuracy: 0.9075
# saved new val_loss
# Epoch 11/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.2250 - accuracy: 0.9319 - val_loss: 0.2907 - val_accuracy: 0.9125
# saved new val_loss
# saved new val_accuracy
# Epoch 12/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.2027 - accuracy: 0.9394 - val_loss: 0.2933 - val_accuracy: 0.9125
# Epoch 13/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.2126 - accuracy: 0.9393 - val_loss: 0.2918 - val_accuracy: 0.9125
# Epoch 14/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1980 - accuracy: 0.9370 - val_loss: 0.2809 - val_accuracy: 0.9200
# saved new val_loss
# saved new val_accuracy
# Epoch 15/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1938 - accuracy: 0.9453 - val_loss: 0.2734 - val_accuracy: 0.9175
# saved new val_loss
# Epoch 16/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1783 - accuracy: 0.9475 - val_loss: 0.2706 - val_accuracy: 0.9150
# saved new val_loss
# Epoch 17/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1783 - accuracy: 0.9541 - val_loss: 0.2756 - val_accuracy: 0.9150
# Epoch 18/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1748 - accuracy: 0.9493 - val_loss: 0.2731 - val_accuracy: 0.9050
# Epoch 19/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1667 - accuracy: 0.9542 - val_loss: 0.2762 - val_accuracy: 0.9100
# Epoch 20/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1653 - accuracy: 0.9481 - val_loss: 0.2674 - val_accuracy: 0.9150
# saved new val_loss
# Epoch 21/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1588 - accuracy: 0.9474 - val_loss: 0.2719 - val_accuracy: 0.9125
# Epoch 22/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1344 - accuracy: 0.9608 - val_loss: 0.2660 - val_accuracy: 0.9100
# saved new val_loss
# Epoch 23/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1352 - accuracy: 0.9630 - val_loss: 0.2678 - val_accuracy: 0.9175
# Epoch 24/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1507 - accuracy: 0.9562 - val_loss: 0.2642 - val_accuracy: 0.9250
# saved new val_loss
# saved new val_accuracy
# Epoch 25/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1499 - accuracy: 0.9587 - val_loss: 0.2641 - val_accuracy: 0.9225
# saved new val_loss
# Epoch 26/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1267 - accuracy: 0.9637 - val_loss: 0.2689 - val_accuracy: 0.9150
# Epoch 27/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1374 - accuracy: 0.9593 - val_loss: 0.2670 - val_accuracy: 0.9200
# Epoch 28/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1337 - accuracy: 0.9571 - val_loss: 0.2615 - val_accuracy: 0.9175
# saved new val_loss
# Epoch 29/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1233 - accuracy: 0.9662 - val_loss: 0.2619 - val_accuracy: 0.9150
# Epoch 30/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1296 - accuracy: 0.9671 - val_loss: 0.2671 - val_accuracy: 0.9225
# Epoch 31/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1295 - accuracy: 0.9600 - val_loss: 0.2623 - val_accuracy: 0.9250
# Epoch 32/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1453 - accuracy: 0.9597 - val_loss: 0.2619 - val_accuracy: 0.9200
# Epoch 33/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1133 - accuracy: 0.9701 - val_loss: 0.2562 - val_accuracy: 0.9275
# saved new val_loss
# saved new val_accuracy
# Epoch 34/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1255 - accuracy: 0.9654 - val_loss: 0.2578 - val_accuracy: 0.9250
# Epoch 35/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1090 - accuracy: 0.9710 - val_loss: 0.2538 - val_accuracy: 0.9250
# saved new val_loss
# Epoch 36/100
# 113/113 [==============================] - 3s 26ms/step - loss: 0.1155 - accuracy: 0.9654 - val_loss: 0.2551 - val_accuracy: 0.9225
# Epoch 37/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1184 - accuracy: 0.9691 - val_loss: 0.2567 - val_accuracy: 0.9225
# Epoch 38/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1159 - accuracy: 0.9750 - val_loss: 0.2545 - val_accuracy: 0.9200
# Epoch 39/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1131 - accuracy: 0.9691 - val_loss: 0.2569 - val_accuracy: 0.9175
# Epoch 40/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1036 - accuracy: 0.9693 - val_loss: 0.2557 - val_accuracy: 0.9250
# Epoch 41/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1009 - accuracy: 0.9747 - val_loss: 0.2543 - val_accuracy: 0.9275
# Epoch 42/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1058 - accuracy: 0.9737 - val_loss: 0.2519 - val_accuracy: 0.9300
# saved new val_loss
# saved new val_accuracy
# Epoch 43/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1144 - accuracy: 0.9664 - val_loss: 0.2485 - val_accuracy: 0.9300
# saved new val_loss
# Epoch 44/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0888 - accuracy: 0.9745 - val_loss: 0.2533 - val_accuracy: 0.9250
# Epoch 45/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0898 - accuracy: 0.9751 - val_loss: 0.2507 - val_accuracy: 0.9225
# Epoch 46/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0834 - accuracy: 0.9839 - val_loss: 0.2527 - val_accuracy: 0.9300
# Epoch 47/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0907 - accuracy: 0.9806 - val_loss: 0.2502 - val_accuracy: 0.9300
# Epoch 48/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0983 - accuracy: 0.9728 - val_loss: 0.2498 - val_accuracy: 0.9275
# Epoch 49/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.1061 - accuracy: 0.9733 - val_loss: 0.2510 - val_accuracy: 0.9325
# saved new val_accuracy
# Epoch 50/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0950 - accuracy: 0.9699 - val_loss: 0.2493 - val_accuracy: 0.9250
# Epoch 51/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0964 - accuracy: 0.9764 - val_loss: 0.2435 - val_accuracy: 0.9250
# saved new val_loss
# Epoch 52/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0912 - accuracy: 0.9733 - val_loss: 0.2486 - val_accuracy: 0.9275
# Epoch 53/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0926 - accuracy: 0.9743 - val_loss: 0.2481 - val_accuracy: 0.9275
# Epoch 54/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0890 - accuracy: 0.9769 - val_loss: 0.2474 - val_accuracy: 0.9350
# saved new val_accuracy
# Epoch 55/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0947 - accuracy: 0.9768 - val_loss: 0.2510 - val_accuracy: 0.9325
# Epoch 56/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0901 - accuracy: 0.9767 - val_loss: 0.2480 - val_accuracy: 0.9325
# Epoch 57/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0947 - accuracy: 0.9692 - val_loss: 0.2484 - val_accuracy: 0.9300
# Epoch 58/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0962 - accuracy: 0.9729 - val_loss: 0.2460 - val_accuracy: 0.9275
# Epoch 59/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0835 - accuracy: 0.9813 - val_loss: 0.2471 - val_accuracy: 0.9225
# Epoch 60/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0896 - accuracy: 0.9761 - val_loss: 0.2479 - val_accuracy: 0.9225
# Epoch 61/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0804 - accuracy: 0.9811 - val_loss: 0.2472 - val_accuracy: 0.9275
# Epoch 62/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0876 - accuracy: 0.9783 - val_loss: 0.2466 - val_accuracy: 0.9250
# Epoch 63/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0785 - accuracy: 0.9813 - val_loss: 0.2456 - val_accuracy: 0.9350
# Epoch 64/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0865 - accuracy: 0.9753 - val_loss: 0.2452 - val_accuracy: 0.9350
# Epoch 65/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0803 - accuracy: 0.9805 - val_loss: 0.2531 - val_accuracy: 0.9325
# Epoch 66/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0730 - accuracy: 0.9807 - val_loss: 0.2508 - val_accuracy: 0.9275
# Epoch 67/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0885 - accuracy: 0.9746 - val_loss: 0.2501 - val_accuracy: 0.9275
# Epoch 68/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0746 - accuracy: 0.9763 - val_loss: 0.2486 - val_accuracy: 0.9225
# Epoch 69/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0764 - accuracy: 0.9806 - val_loss: 0.2513 - val_accuracy: 0.9275
# Epoch 70/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0799 - accuracy: 0.9769 - val_loss: 0.2528 - val_accuracy: 0.9300
# Epoch 71/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0679 - accuracy: 0.9845 - val_loss: 0.2517 - val_accuracy: 0.9250
# Epoch 72/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0750 - accuracy: 0.9807 - val_loss: 0.2481 - val_accuracy: 0.9350
# Epoch 73/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0768 - accuracy: 0.9852 - val_loss: 0.2514 - val_accuracy: 0.9350
# Epoch 74/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0793 - accuracy: 0.9819 - val_loss: 0.2528 - val_accuracy: 0.9350
# Epoch 75/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0710 - accuracy: 0.9834 - val_loss: 0.2509 - val_accuracy: 0.9375
# saved new val_accuracy
# Epoch 76/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0792 - accuracy: 0.9762 - val_loss: 0.2534 - val_accuracy: 0.9300
# Epoch 77/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0803 - accuracy: 0.9754 - val_loss: 0.2497 - val_accuracy: 0.9300
# Epoch 78/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0754 - accuracy: 0.9811 - val_loss: 0.2484 - val_accuracy: 0.9350
# Epoch 79/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0784 - accuracy: 0.9813 - val_loss: 0.2478 - val_accuracy: 0.9325
# Epoch 80/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0674 - accuracy: 0.9826 - val_loss: 0.2468 - val_accuracy: 0.9325
# Epoch 81/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0665 - accuracy: 0.9847 - val_loss: 0.2519 - val_accuracy: 0.9350
# Epoch 82/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0768 - accuracy: 0.9784 - val_loss: 0.2505 - val_accuracy: 0.9325
# Epoch 83/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0686 - accuracy: 0.9818 - val_loss: 0.2455 - val_accuracy: 0.9250
# Epoch 84/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0657 - accuracy: 0.9816 - val_loss: 0.2466 - val_accuracy: 0.9300
# Epoch 85/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0711 - accuracy: 0.9801 - val_loss: 0.2501 - val_accuracy: 0.9300
# Epoch 86/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0661 - accuracy: 0.9830 - val_loss: 0.2459 - val_accuracy: 0.9300
# Epoch 87/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0665 - accuracy: 0.9854 - val_loss: 0.2500 - val_accuracy: 0.9325
# Epoch 88/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0733 - accuracy: 0.9779 - val_loss: 0.2471 - val_accuracy: 0.9350
# Epoch 89/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0725 - accuracy: 0.9804 - val_loss: 0.2461 - val_accuracy: 0.9325
# Epoch 90/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0620 - accuracy: 0.9849 - val_loss: 0.2474 - val_accuracy: 0.9325
# Epoch 91/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0660 - accuracy: 0.9843 - val_loss: 0.2484 - val_accuracy: 0.9300
# Epoch 92/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0722 - accuracy: 0.9832 - val_loss: 0.2504 - val_accuracy: 0.9325
# Epoch 93/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0641 - accuracy: 0.9848 - val_loss: 0.2474 - val_accuracy: 0.9350
# Epoch 94/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0611 - accuracy: 0.9862 - val_loss: 0.2467 - val_accuracy: 0.9325
# Epoch 95/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0581 - accuracy: 0.9872 - val_loss: 0.2475 - val_accuracy: 0.9350
# Epoch 96/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0654 - accuracy: 0.9820 - val_loss: 0.2472 - val_accuracy: 0.9325
# Epoch 97/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0583 - accuracy: 0.9872 - val_loss: 0.2495 - val_accuracy: 0.9325
# Epoch 98/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0625 - accuracy: 0.9847 - val_loss: 0.2509 - val_accuracy: 0.9325
# Epoch 99/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0733 - accuracy: 0.9799 - val_loss: 0.2525 - val_accuracy: 0.9325
# Epoch 100/100
# 113/113 [==============================] - 3s 27ms/step - loss: 0.0609 - accuracy: 0.9822 - val_loss: 0.2514 - val_accuracy: 0.9300
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.12/13_bot_4/ep_50_val_loss_0.243454247713089/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.12/13_bot_4/ep_74_val_accuracy_0.9375/assets
# Finished Training

# %%
import pandas as pd
     
# dictionary of lists  
this_dict = {'training loss': training_loss_list, 'training acc': training_acc_list, 'val loss': val_loss_list, 'val acc':val_acc_list}  
       
df = pd.DataFrame(this_dict) 
    
# saving the dataframe 
df.to_csv(os.path.join(root_dir, 'logs.csv'))

# %%
y_int = y.argmax(1)

# %%
unique, counts = np.unique(y_int, return_counts=True)
dict(zip(unique, counts))

# %%
unique, counts = np.unique(val_y.argmax(1), return_counts=True)
dict(zip(unique, counts))

# %%
np.savez_compressed('/content/drive/MyDrive/Cache/keras/train_val', x=x, y=y, x_val=val_x, y_val=val_y)

# %%
print(val_y)

# %%
print(inputs.shape)

# %%
cp = torch.load(os.path.join(root_dir, 'last.pt'))
model.load_state_dict(cp['state_dict'])
optimizer.load_state_dict(cp['optimizer'])
last_epoch_done = cp['epoch'] - 1

# %%
#continue training


if not os.path.exists(root_dir):
    os.makedirs(root_dir)


low_val_loss = 30000000
best_acc = -1
epoch = 0

val_loss_path = None
acc_path = None
#https://stackoverflow.com/questions/8078330/csv-writing-within-loop
import csv
with open(os.path.join(root_dir, 'logs2.csv'), 'w') as file_csv:
  writer=csv.writer(file_csv, delimiter=',',lineterminator='\n',)
  writer.writerow(['epoch', 'loss', 'acc', 'val_loss', 'val_acc'])


  for epoch in range(last_epoch_done, 101):
      row = [epoch]
      is_best = False
      running_loss = 0.0
      correct = 0
      total = 0

      model.train()

      t0 = time.time()
      for i, data in enumerate(training_loader):
          # get the inputs; data is a list of [inputs, labels]
          inputs, labels = data

          # for this_view in range(inputs.shape[1]):
          #   if np.random.randint(0, 4) == 0:
          #     inputs[:, this_view, ...] = 1.0

          inputs = inputs.to(device)
          labels = labels.to(device)

          # zero the parameter gradients
          optimizer.zero_grad()

          # forward + backward + optimize
          outputs = model(inputs)
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()

          # print statistics
          correct += (outputs.argmax(1) == labels).float().sum() #https://stackoverflow.com/questions/51503851/calculate-the-accuracy-every-epoch-in-pytorch
          total += labels.shape[0]
          running_loss += loss.item()

      print('epoch', epoch)
      
      print('{} seconds'.format(time.time() - t0))
      print('loss', running_loss)
      row.append(running_loss)
      running_loss = 0.0

      accuracy = 100 * correct / total
      print("Accuracy = {}".format(accuracy))
      row.append(torch.IntTensor.item(accuracy))
      correct = 0
      total= 0

      running_loss = 0.0
      correct = 0
      total = 0

      optimizer.zero_grad()
      model.eval()
      t0 = time.time()
      with torch.no_grad():
          for i, data in enumerate(val_loader):
              
              # get the inputs; data is a list of [inputs, labels]
              inputs, labels = data
              inputs = inputs.to(device)
              labels = labels.to(device)            


              # forward + backward + optimize
              outputs = model(inputs)
              loss = criterion(outputs, labels)

              correct += (outputs.argmax(1) == labels).float().sum() #https://stackoverflow.com/questions/51503851/calculate-the-accuracy-every-epoch-in-pytorch
              total += labels.shape[0]
              running_loss += loss.item()

      print('{} seconds'.format(time.time() - t0))
      print('val loss', running_loss)
      row.append(running_loss)
      

      accuracy = 100 * correct / total
      print(" Val Accuracy = {}".format(accuracy))
      row.append(torch.IntTensor.item(accuracy))

      model_name = 'ep_' + str(epoch) + '_loss_' + str(running_loss) + '_acc_' + str(accuracy) + '.pt'
      full_model_path = os.path.join(root_dir, model_name)
      checkpoint = {
          'epoch': epoch + 1,
          'state_dict': model.state_dict(),
          'optimizer': optimizer.state_dict()
      }
      if running_loss < low_val_loss:
        if val_loss_path and os.path.exists(val_loss_path):
          open(val_loss_path, 'w').close() #overwrite and make the file blank instead - ref: https://stackoverflow.com/a/4914288/3553367
          os.remove(val_loss_path)
        val_loss_path = full_model_path.replace('.pt', 'val_loss_best.pt')
        save_ckp(model, val_loss_path)
        low_val_loss = running_loss
        print('new low loss')

      if accuracy > best_acc:
        if acc_path and os.path.exists(acc_path):
          open(acc_path, 'w').close() #overwrite and make the file blank instead - ref: https://stackoverflow.com/a/4914288/3553367
          os.remove(acc_path)
        acc_path = full_model_path.replace('.pt', 'acc_best.pt')
        save_ckp(model, acc_path)
        best_acc = accuracy
        print('new best acc')
      full_model_path = os.path.join(root_dir, 'last.pt')
      save_ckp(checkpoint, full_model_path)
          

      

      correct = 0
      total= 0
      running_loss = 0.0
      writer.writerow(row)
  print('Finished Training')
