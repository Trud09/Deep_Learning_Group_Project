# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import multiprocessing
import numpy as np
import cv2
import time
import shutil

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
from torchvision import transforms

# %%
if torch.cuda.is_available():  
  dev = "cuda:0" 
else:  
  dev = "cpu"  

device = torch.device(dev)
print(device)
# Out:
# cuda:0

# %%
# !nvidia-smi
# Out:
# Mon Apr 26 05:36:33 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    30W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#https://towardsdatascience.com/implementing-the-new-state-of-the-art-mish-activation-with-2-lines-of-code-in-pytorch-e7ef438a5ee7
def mish(x): 
  return (x * torch.tanh(nn.functional.softplus(x)))

#https://machinelearningmastery.com/pytorch-tutorial-develop-deep-learning-models/
class Model_3d(nn.Module):
    '''
    A model to use on 3d objects
    '''
    def __init__(self, fc_nodes, no_views, no_classes):
      super(Model_3d, self).__init__()
      self.resnet = torchvision.models.resnet50(pretrained=True) #https://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html

      num_features = self.resnet.fc.out_features

      self.fcs = nn.ModuleList()

      for idx in range(no_views):
        self.fcs.append(nn.Linear(num_features, fc_nodes))


      self.final_dense = nn.Linear(fc_nodes * no_views, no_classes)
    
    def forward(self, x):
      features = []

      for i, fc in enumerate(self.fcs):
        sample = x[:, i, ...]
        r_out = self.resnet(sample)

        fc_out = fc(r_out)
        features.append(fc_out)
      
      stack = torch.stack(features, 1)

      reshaped = stack.view([x.shape[0], -1])

      mish_out = mish(reshaped)

      x = self.final_dense(mish_out)


      return torch.nn.functional.softmax(x)

# %%
class Date_3d_Cached(torch.utils.data.Dataset):
    def __init__(self, x, y):
      self.x = torch.from_numpy(x)
      self.y = torch.from_numpy(y)
    
    def __len__(self):
      return self.x.shape[0]

    def __getitem__(self, idx):
      return self.x[idx] /255.0, self.y[idx]

# %%
views = ['bottom', 'side_1', 'side_2', 'side_3', 'side_4', 'top']
x = np.load('/content/drive/MyDrive/Cache/x.npy')
y = np.load('/content/drive/MyDrive/Cache/y.npy')

training_data = Date_3d_Cached(x, y)

# %%
#90/10 train val split
train_len = int(len(training_data) * .9)
val_len = len(training_data) - train_len

# %%
train_set, val_set = torch.utils.data.random_split(training_data, [train_len, val_len],torch.Generator().manual_seed(42))

# %%
batch_size = 16

# %%
model = Model_3d(1024, len(views), 10)
model.to(device)
print(device)
training_loader = torch.utils.data.DataLoader(train_set, batch_size= batch_size, shuffle=True, num_workers=os.cpu_count())
val_loader = torch.utils.data.DataLoader(val_set, batch_size= batch_size, shuffle=True, num_workers=os.cpu_count())
# Out:
# cuda:0

# %%
print(os.cpu_count())
print(train_len)
print(val_len)
# Out:
# 2
# 3591
# 400

# %%
#https://medium.com/analytics-vidhya/saving-and-loading-your-model-to-resume-training-in-pytorch-cb687352fa61
def save_ckp(state, model_path):
    torch.save(state, model_path)

# %%
#https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

root_dir = '/content/drive/MyDrive/Models_R50_mish_t2'
if not os.path.exists(root_dir):
    os.makedirs(root_dir)


low_val_loss = 30000000
best_acc = -1
epoch = 0

val_loss_path = None
acc_path = None
#https://stackoverflow.com/questions/8078330/csv-writing-within-loop
import csv
with open(os.path.join(root_dir, 'logs.csv'), 'w') as file_csv:
  writer=csv.writer(file_csv, delimiter=',',lineterminator='\n',)
  writer.writerow(['epoch', 'loss', 'acc', 'val_loss', 'val_acc'])


  for epoch in range(1, 301):
      row = [epoch]
      is_best = False
      running_loss = 0.0
      correct = 0
      total = 0

      model.train()

      t0 = time.time()
      for i, data in enumerate(training_loader):
          # get the inputs; data is a list of [inputs, labels]
          inputs, labels = data
          inputs = inputs.to(device)
          labels = labels.to(device)

          # zero the parameter gradients
          optimizer.zero_grad()

          # forward + backward + optimize
          outputs = model(inputs)
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()

          # print statistics
          correct += (outputs.argmax(1) == labels).float().sum() #https://stackoverflow.com/questions/51503851/calculate-the-accuracy-every-epoch-in-pytorch
          total += labels.shape[0]
          running_loss += loss.item()

      print('epoch', epoch)
      
      print('{} seconds'.format(time.time() - t0))
      print('loss', running_loss)
      row.append(running_loss)
      running_loss = 0.0

      accuracy = 100 * correct / total
      print("Accuracy = {}".format(accuracy))
      row.append(torch.IntTensor.item(accuracy))
      correct = 0
      total= 0

      running_loss = 0.0
      correct = 0
      total = 0

      optimizer.zero_grad()
      model.eval()
      t0 = time.time()
      with torch.no_grad():
          for i, data in enumerate(val_loader):
              
              # get the inputs; data is a list of [inputs, labels]
              inputs, labels = data
              inputs = inputs.to(device)
              labels = labels.to(device)            


              # forward + backward + optimize
              outputs = model(inputs)
              loss = criterion(outputs, labels)

              correct += (outputs.argmax(1) == labels).float().sum() #https://stackoverflow.com/questions/51503851/calculate-the-accuracy-every-epoch-in-pytorch
              total += labels.shape[0]
              running_loss += loss.item()

      print('{} seconds'.format(time.time() - t0))
      print('val loss', running_loss)
      row.append(running_loss)
      

      accuracy = 100 * correct / total
      print(" Val Accuracy = {}".format(accuracy))
      row.append(torch.IntTensor.item(accuracy))

      model_name = 'ep_' + str(epoch) + '_loss_' + str(running_loss) + '_acc_' + str(accuracy) + '.pt'
      full_model_path = os.path.join(root_dir, model_name)
      checkpoint = {
          'epoch': epoch + 1,
          'state_dict': model.state_dict(),
          'optimizer': optimizer.state_dict()
      }
      if running_loss < low_val_loss:
        if val_loss_path and os.path.exists(val_loss_path):
          os.remove(val_loss_path)
        val_loss_path = full_model_path.replace('.pt', 'val_loss_best.pt')
        save_ckp(model, val_loss_path)
        low_val_loss = running_loss
        print('new low loss')

      if accuracy > best_acc:
        if acc_path and os.path.exists(acc_path):
          os.remove(acc_path)
        acc_path = full_model_path.replace('.pt', 'acc_best.pt')
        save_ckp(model, acc_path)
        best_acc = accuracy
        print('new best acc')
      full_model_path = os.path.join(root_dir, 'last.pt')
      save_ckp(checkpoint, full_model_path)
          

      

      correct = 0
      total= 0
      running_loss = 0.0
      writer.writerow(row)
  print('Finished Training')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:43: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# epoch 1
# 124.46230626106262 seconds
# loss 405.7195688486099
# Accuracy = 68.28182220458984
# 4.972508907318115 seconds
# val loss 41.07002031803131
#  Val Accuracy = 83.25
# new low loss
# new best acc
# epoch 2
# 124.83247542381287 seconds
# loss 363.417648434639
# Accuracy = 85.32442474365234
# 4.94437575340271 seconds
# val loss 40.63933515548706
#  Val Accuracy = 84.0
# new low loss
# new best acc
# epoch 3
# 124.73604249954224 seconds
# loss 356.4995183944702
# Accuracy = 88.49903106689453
# 4.951541423797607 seconds
# val loss 39.3389447927475
#  Val Accuracy = 89.25
# new low loss
# new best acc
# epoch 4
# 124.80589246749878 seconds
# loss 352.3622250556946
# Accuracy = 90.08633422851562
# 4.984593868255615 seconds
# val loss 39.169169664382935
#  Val Accuracy = 90.25
# new low loss
# new best acc
# epoch 5
# 124.77654147148132 seconds
# loss 346.836856842041
# Accuracy = 92.8710708618164
# 4.973254919052124 seconds
# val loss 38.53315234184265
#  Val Accuracy = 92.25
# new low loss
# new best acc
# epoch 6
# 124.74140286445618 seconds
# loss 342.5344924926758
# Accuracy = 94.62545776367188
# 4.947465896606445 seconds
# val loss 38.16510462760925
#  Val Accuracy = 94.0
# new low loss
# new best acc
# epoch 7
# 124.52952694892883 seconds
# loss 340.0890347957611
# Accuracy = 95.54441833496094
# 4.940561532974243 seconds
# val loss 38.091885805130005
#  Val Accuracy = 93.75
# new low loss
# epoch 8
# 124.63975954055786 seconds
# loss 337.0027405023575
# Accuracy = 96.99248504638672
# 4.922147989273071 seconds
# val loss 37.83744275569916
#  Val Accuracy = 95.75
# new low loss
# new best acc
# epoch 9
# 124.7241222858429 seconds
# loss 333.01529681682587
# Accuracy = 98.83041381835938
# 5.005686521530151 seconds
# val loss 37.47732174396515
#  Val Accuracy = 97.0
# new low loss
# new best acc
# epoch 10
# 124.79876184463501 seconds
# loss 331.3265664577484
# Accuracy = 99.16458129882812
# 4.941351890563965 seconds
# val loss 37.52175426483154
#  Val Accuracy = 96.5
# epoch 11
# 125.08956456184387 seconds
# loss 331.19405829906464
# Accuracy = 99.3316650390625
# 4.921831369400024 seconds
# val loss 37.53668129444122
#  Val Accuracy = 96.25
# epoch 12
# 124.61907172203064 seconds
# loss 330.3634548187256
# Accuracy = 99.61013793945312
# 4.950444221496582 seconds
# val loss 37.40805959701538
#  Val Accuracy = 97.0
# new low loss
# epoch 13
# 124.70811367034912 seconds
# loss 330.3273411989212
# Accuracy = 99.554443359375
# 4.95624303817749 seconds
# val loss 37.46662783622742
#  Val Accuracy = 96.75
# epoch 14
# 124.55066800117493 seconds
# loss 330.1576147079468
# Accuracy = 99.58229064941406
# 4.999113321304321 seconds
# val loss 37.35438692569733
#  Val Accuracy = 97.25
# new low loss
# new best acc
# epoch 15
# 124.72926926612854 seconds
# loss 329.93495285511017
# Accuracy = 99.63799285888672
# 4.9589080810546875 seconds
# val loss 37.61785674095154
#  Val Accuracy = 96.25
# epoch 16
# 124.53060007095337 seconds
# loss 329.9439822435379
# Accuracy = 99.61013793945312
# 4.942091226577759 seconds
# val loss 37.371681451797485
#  Val Accuracy = 96.75
# epoch 17
# 124.64604878425598 seconds
# loss 329.82751870155334
# Accuracy = 99.66584014892578
# 4.962634086608887 seconds
# val loss 37.30117869377136
#  Val Accuracy = 97.5
# new low loss
# new best acc
# epoch 18
# 124.78316235542297 seconds
# loss 329.66885471343994
# Accuracy = 99.69368743896484
# 4.965277910232544 seconds
# val loss 37.424492835998535
#  Val Accuracy = 96.75
# epoch 19
# 124.75742816925049 seconds
# loss 329.64566719532013
# Accuracy = 99.7215347290039
# 4.950091123580933 seconds
# val loss 37.3379852771759
#  Val Accuracy = 97.25
# epoch 20
# 124.80345797538757 seconds
# loss 329.5449322462082
# Accuracy = 99.7215347290039
# 4.9643754959106445 seconds
# val loss 37.408841490745544
#  Val Accuracy = 96.5
# epoch 21
# 124.69509530067444 seconds
# loss 329.55707263946533
# Accuracy = 99.74938201904297
# 4.935035228729248 seconds
# val loss 37.41117835044861
#  Val Accuracy = 96.5
# epoch 22
# 124.7954797744751 seconds
# loss 329.54174625873566
# Accuracy = 99.74938201904297
# 4.935956239700317 seconds
# val loss 37.307443499565125
#  Val Accuracy = 97.5
# epoch 23
# 124.80934357643127 seconds
# loss 329.36851739883423
# Accuracy = 99.77722930908203
# 4.926255941390991 seconds
# val loss 37.205169796943665
#  Val Accuracy = 97.75
# new low loss
# new best acc
# epoch 24
# 124.83211469650269 seconds
# loss 329.4036148786545
# Accuracy = 99.77722930908203
# 4.961158752441406 seconds
# val loss 37.41570734977722
#  Val Accuracy = 96.5
# epoch 25
# 124.65175199508667 seconds
# loss 329.3802387714386
# Accuracy = 99.8050765991211
# 4.913438558578491 seconds
# val loss 37.28861737251282
#  Val Accuracy = 97.25
# epoch 26
# 124.58997321128845 seconds
# loss 329.24538397789
# Accuracy = 99.83292388916016
# 4.937331199645996 seconds
# val loss 37.34340059757233
#  Val Accuracy = 96.75
# epoch 27
# 124.7418212890625 seconds
# loss 329.2606987953186
# Accuracy = 99.83292388916016
# 4.9510817527771 seconds
# val loss 37.34230697154999
#  Val Accuracy = 97.25
# epoch 28
# 124.62760877609253 seconds
# loss 329.35774862766266
# Accuracy = 99.8050765991211
# 4.96458625793457 seconds
# val loss 37.42205250263214
#  Val Accuracy = 96.25
# epoch 29
# 124.80236458778381 seconds
# loss 329.40338003635406
# Accuracy = 99.77722930908203
# 4.961671352386475 seconds
# val loss 37.23264265060425
#  Val Accuracy = 97.75
# epoch 30
# 124.75315856933594 seconds
# loss 329.3021157979965
# Accuracy = 99.83292388916016
# 5.026514291763306 seconds
# val loss 37.25329101085663
#  Val Accuracy = 97.25
# epoch 31
# 124.74173164367676 seconds
# loss 329.21820056438446
# Accuracy = 99.83292388916016
# 5.098406553268433 seconds
# val loss 37.20714604854584
#  Val Accuracy = 97.75
# epoch 32
# 124.83322286605835 seconds
# loss 329.27710235118866
# Accuracy = 99.8050765991211
# 4.9973320960998535 seconds
# val loss 37.278554916381836
#  Val Accuracy = 97.5
# epoch 33
# 124.79987907409668 seconds
# loss 329.25426852703094
# Accuracy = 99.83292388916016
# 5.002316236495972 seconds
# val loss 37.20934224128723
#  Val Accuracy = 97.75
# epoch 34
# 124.90580010414124 seconds
# loss 329.36952900886536
# Accuracy = 99.83292388916016
# 4.974440336227417 seconds
# val loss 37.34963071346283
#  Val Accuracy = 97.25
# epoch 35
# 124.75180268287659 seconds
# loss 329.4155224561691
# Accuracy = 99.77722930908203
# 4.978301525115967 seconds
# val loss 37.35532891750336
#  Val Accuracy = 96.5
# epoch 36
# 124.84171986579895 seconds
# loss 329.2616517543793
# Accuracy = 99.83292388916016
# 4.952251672744751 seconds
# val loss 37.24606263637543
#  Val Accuracy = 97.25
# epoch 37
# 124.84058570861816 seconds
# loss 329.19801938533783
# Accuracy = 99.83292388916016
# 4.961787462234497 seconds
# val loss 37.33227813243866
#  Val Accuracy = 97.25
# epoch 38
# 124.82109093666077 seconds
# loss 329.2329080104828
# Accuracy = 99.83292388916016
# 4.941465377807617 seconds
# val loss 37.368982791900635
#  Val Accuracy = 96.5
# epoch 39
# 124.9219753742218 seconds
# loss 329.24072551727295
# Accuracy = 99.83292388916016
# 4.964733600616455 seconds
# val loss 37.32063436508179
#  Val Accuracy = 97.0
# epoch 40
# 124.77239084243774 seconds
# loss 329.2737832069397
# Accuracy = 99.8050765991211
# 5.032164573669434 seconds
# val loss 37.39038336277008
#  Val Accuracy = 96.75
# epoch 41
# 124.78834104537964 seconds
# loss 329.2850685119629
# Accuracy = 99.8050765991211
# 4.9509875774383545 seconds
# val loss 37.32490932941437
#  Val Accuracy = 97.0
# epoch 42
# 124.82238960266113 seconds
# loss 329.2255860567093
# Accuracy = 99.83292388916016
# 4.947831153869629 seconds
# val loss 37.35081231594086
#  Val Accuracy = 97.0
# epoch 43
# 124.7622697353363 seconds
# loss 329.1792701482773
# Accuracy = 99.83292388916016
# 4.953701972961426 seconds
# val loss 37.344908118247986
#  Val Accuracy = 97.25
# epoch 44
# 124.80711603164673 seconds
# loss 329.19215309619904
# Accuracy = 99.83292388916016
# 4.969961404800415 seconds
# val loss 37.2077921628952
#  Val Accuracy = 97.75
# epoch 45
# 124.7838454246521 seconds
# loss 329.1826146841049
# Accuracy = 99.83292388916016
# 4.9455790519714355 seconds
# val loss 37.21456706523895
#  Val Accuracy = 97.5
# epoch 46
# 124.79791688919067 seconds
# loss 329.19046652317047
# Accuracy = 99.83292388916016
# 4.959420204162598 seconds
# val loss 37.46131885051727
#  Val Accuracy = 96.5
# epoch 47
# 125.01726388931274 seconds
# loss 329.1690402030945
# Accuracy = 99.83292388916016
# 5.0671961307525635 seconds
# val loss 37.23055016994476
#  Val Accuracy = 97.75
# epoch 48
# 124.89491605758667 seconds
# loss 329.2188376188278
# Accuracy = 99.8050765991211
# 4.955024719238281 seconds
# val loss 37.36984133720398
#  Val Accuracy = 97.0
# epoch 49
# 124.75536632537842 seconds
# loss 329.17705965042114
# Accuracy = 99.83292388916016
# 5.011403799057007 seconds
# val loss 37.30151879787445
#  Val Accuracy = 97.25
# epoch 50
# 124.75213527679443 seconds
# loss 329.1629114151001
# Accuracy = 99.83292388916016
# 4.953004837036133 seconds
# val loss 37.20602774620056
#  Val Accuracy = 97.5
# epoch 51
# 124.73473358154297 seconds
# loss 329.15768551826477
# Accuracy = 99.83292388916016
# 4.9621901512146 seconds
# val loss 37.45341634750366
#  Val Accuracy = 96.5
# epoch 52
# 124.73831343650818 seconds
# loss 329.1809343099594
# Accuracy = 99.83292388916016
# 4.994936227798462 seconds
# val loss 37.269406914711
#  Val Accuracy = 97.5
# epoch 53
# 124.89309549331665 seconds
# loss 329.1623418331146
# Accuracy = 99.83292388916016
# 4.946746349334717 seconds
# val loss 37.232028126716614
#  Val Accuracy = 97.25
# epoch 54
# 124.94709038734436 seconds
# loss 329.1696640253067
# Accuracy = 99.83292388916016
# 4.951518297195435 seconds
# val loss 37.206117033958435
#  Val Accuracy = 97.5
# epoch 55
# 124.75275945663452 seconds
# loss 329.1661231517792
# Accuracy = 99.83292388916016
# 4.9651947021484375 seconds
# val loss 37.24217104911804
#  Val Accuracy = 97.5
# epoch 56
# 124.82924795150757 seconds
# loss 329.1760995388031
# Accuracy = 99.83292388916016
# 4.972239971160889 seconds
# val loss 37.252641439437866
#  Val Accuracy = 97.0
# epoch 57
# 124.81552124023438 seconds
# loss 329.1630800962448
# Accuracy = 99.83292388916016
# 4.96601414680481 seconds
# val loss 37.21777665615082
#  Val Accuracy = 97.5
# epoch 58
# 124.95202708244324 seconds
# loss 329.1745592355728
# Accuracy = 99.83292388916016
# 4.947792291641235 seconds
# val loss 37.40434801578522
#  Val Accuracy = 96.25
# epoch 59
# 124.87332725524902 seconds
# loss 329.1603934764862
# Accuracy = 99.83292388916016
# 5.000807285308838 seconds
# val loss 37.183979511260986
#  Val Accuracy = 97.5
# new low loss
# epoch 60
# 124.97102904319763 seconds
# loss 329.15426445007324
# Accuracy = 99.83292388916016
# 4.932323694229126 seconds
# val loss 37.37800371646881
#  Val Accuracy = 97.0
# epoch 61
# 124.94613480567932 seconds
# loss 329.16641795635223
# Accuracy = 99.83292388916016
# 4.929882049560547 seconds
# val loss 37.17386066913605
#  Val Accuracy = 97.75
# new low loss
# epoch 62
# 124.93980097770691 seconds
# loss 329.1759957075119
# Accuracy = 99.83292388916016
# 4.980521202087402 seconds
# val loss 37.38625741004944
#  Val Accuracy = 97.0
# epoch 63
# 124.84276413917542 seconds
# loss 329.1584942340851
# Accuracy = 99.83292388916016
# 4.963033676147461 seconds
# val loss 37.176851749420166
#  Val Accuracy = 97.5
# epoch 64
# 124.79902338981628 seconds
# loss 329.14948523044586
# Accuracy = 99.83292388916016
# 4.97866415977478 seconds
# val loss 37.40574240684509
#  Val Accuracy = 96.5
# epoch 65
# 124.89422821998596 seconds
# loss 329.15134274959564
# Accuracy = 99.83292388916016
# 4.976470232009888 seconds
# val loss 37.35090363025665
#  Val Accuracy = 97.0
# epoch 66
# 124.86492347717285 seconds
# loss 329.14595580101013
# Accuracy = 99.83292388916016
# 4.961138963699341 seconds
# val loss 37.30763220787048
#  Val Accuracy = 97.0
# epoch 67
# 124.9048182964325 seconds
# loss 329.15854477882385
# Accuracy = 99.83292388916016
# 4.971942186355591 seconds
# val loss 37.30444586277008
#  Val Accuracy = 96.75
# epoch 68
# 124.95487976074219 seconds
# loss 329.1791067123413
# Accuracy = 99.83292388916016
# 4.979181289672852 seconds
# val loss 37.238568902015686
#  Val Accuracy = 97.0
# epoch 69
# 124.94942498207092 seconds
# loss 329.17787289619446
# Accuracy = 99.83292388916016
# 4.981999635696411 seconds
# val loss 37.154523849487305
#  Val Accuracy = 97.75
# new low loss
# epoch 70
# 124.77197313308716 seconds
# loss 329.1632753610611
# Accuracy = 99.83292388916016
# 4.950162887573242 seconds
# val loss 37.25468957424164
#  Val Accuracy = 97.25
# epoch 71
# 124.92994046211243 seconds
# loss 329.15400326251984
# Accuracy = 99.83292388916016
# 4.997551918029785 seconds
# val loss 37.3645441532135
#  Val Accuracy = 96.75
# epoch 72
# 124.9693284034729 seconds
# loss 329.1754068136215
# Accuracy = 99.83292388916016
# 4.940913200378418 seconds
# val loss 37.214022517204285
#  Val Accuracy = 97.25
# epoch 73
# 125.11897253990173 seconds
# loss 329.1538288593292
# Accuracy = 99.83292388916016
# 4.933586120605469 seconds
# val loss 37.183175683021545
#  Val Accuracy = 97.5
# epoch 74
# 124.92981433868408 seconds
# loss 329.11747455596924
# Accuracy = 99.86077117919922
# 5.060874700546265 seconds
# val loss 37.135167479515076
#  Val Accuracy = 98.0
# new low loss
# new best acc
# epoch 75
# 124.89000034332275 seconds
# loss 329.09895634651184
# Accuracy = 99.86077117919922
# 4.967998743057251 seconds
# val loss 37.3808536529541
#  Val Accuracy = 96.5
# epoch 76
# 124.66799664497375 seconds
# loss 329.1354706287384
# Accuracy = 99.86077117919922
# 4.958055019378662 seconds
# val loss 37.14963090419769
#  Val Accuracy = 97.75
# epoch 77
# 124.80467200279236 seconds
# loss 329.12264108657837
# Accuracy = 99.86077117919922
# 4.965469598770142 seconds
# val loss 37.176928997039795
#  Val Accuracy = 98.0
# epoch 78
# 124.80207324028015 seconds
# loss 329.09397411346436
# Accuracy = 99.86077117919922
# 4.982532978057861 seconds
# val loss 37.14942109584808
#  Val Accuracy = 98.0
# epoch 79
# 124.82414865493774 seconds
# loss 329.09216022491455
# Accuracy = 99.86077117919922
# 4.928180694580078 seconds
# val loss 37.11561679840088
#  Val Accuracy = 98.0
# new low loss
# epoch 80
# 124.84128594398499 seconds
# loss 329.08772480487823
# Accuracy = 99.86077117919922
# 4.953424692153931 seconds
# val loss 37.17212963104248
#  Val Accuracy = 97.75
# epoch 81
# 124.73784971237183 seconds
# loss 329.13091218471527
# Accuracy = 99.83292388916016
# 4.925539970397949 seconds
# val loss 37.41962921619415
#  Val Accuracy = 96.25
# epoch 82
# 124.72784471511841 seconds
# loss 329.1009318828583
# Accuracy = 99.86077117919922
# 4.953610181808472 seconds
# val loss 37.2061128616333
#  Val Accuracy = 97.5
# epoch 83
# 124.71589493751526 seconds
# loss 329.10072803497314
# Accuracy = 99.86077117919922
# 4.96975040435791 seconds
# val loss 37.23944699764252
#  Val Accuracy = 97.0
# epoch 84
# 124.78154802322388 seconds
# loss 329.0909321308136
# Accuracy = 99.86077117919922
# 4.973984241485596 seconds
# val loss 37.14544904232025
#  Val Accuracy = 97.5
# epoch 85
# 124.78282952308655 seconds
# loss 329.08871710300446
# Accuracy = 99.86077117919922
# 4.975174903869629 seconds
# val loss 37.25490868091583
#  Val Accuracy = 97.5
# epoch 86
# 125.01726603507996 seconds
# loss 329.08576703071594
# Accuracy = 99.86077117919922
# 4.968495607376099 seconds
# val loss 37.33361554145813
#  Val Accuracy = 97.0
# epoch 87
# 125.0203287601471 seconds
# loss 329.1301281452179
# Accuracy = 99.83292388916016
# 4.988250017166138 seconds
# val loss 37.2974134683609
#  Val Accuracy = 97.0
# epoch 88
# 124.76017045974731 seconds
# loss 329.09470188617706
# Accuracy = 99.86077117919922
# 4.957873106002808 seconds
# val loss 37.345179438591
#  Val Accuracy = 96.75
# epoch 89
# 124.88796257972717 seconds
# loss 329.0887576341629
# Accuracy = 99.86077117919922
# 4.982660293579102 seconds
# val loss 37.24992549419403
#  Val Accuracy = 97.25
# epoch 90
# 124.77506899833679 seconds
# loss 329.1066610813141
# Accuracy = 99.86077117919922
# 5.00161075592041 seconds
# val loss 37.16718530654907
#  Val Accuracy = 97.25
# epoch 91
# 124.8694326877594 seconds
# loss 329.1324200630188
# Accuracy = 99.86077117919922
# 4.953251838684082 seconds
# val loss 37.265905022621155
#  Val Accuracy = 96.75
# epoch 92
# 124.81843900680542 seconds
# loss 329.09435427188873
# Accuracy = 99.86077117919922
# 4.940406322479248 seconds
# val loss 37.31869828701019
#  Val Accuracy = 96.75
# epoch 93
# 124.97425770759583 seconds
# loss 329.1102252006531
# Accuracy = 99.86077117919922
# 4.965968132019043 seconds
# val loss 37.51979899406433
#  Val Accuracy = 96.0
# epoch 94
# 125.01759481430054 seconds
# loss 329.1003053188324
# Accuracy = 99.86077117919922
# 4.947009801864624 seconds
# val loss 37.17761993408203
#  Val Accuracy = 97.5
# epoch 95
# 124.88061308860779 seconds
# loss 329.10045182704926
# Accuracy = 99.86077117919922
# 4.9784722328186035 seconds
# val loss 37.30537676811218
#  Val Accuracy = 96.75
# epoch 96
# 124.99790620803833 seconds
# loss 329.08552944660187
# Accuracy = 99.86077117919922
# 5.047102212905884 seconds
# val loss 37.31161451339722
#  Val Accuracy = 97.0
# epoch 97
# 124.91281843185425 seconds
# loss 329.1039237976074
# Accuracy = 99.86077117919922
# 4.974697828292847 seconds
# val loss 37.48105990886688
#  Val Accuracy = 96.25
# epoch 98
# 124.92135071754456 seconds
# loss 329.0858278274536
# Accuracy = 99.86077117919922
# 4.948727130889893 seconds
# val loss 37.3044638633728
#  Val Accuracy = 96.75
# epoch 99
# 124.90483283996582 seconds
# loss 329.0916793346405
# Accuracy = 99.86077117919922
# 4.959283351898193 seconds
# val loss 37.366063475608826
#  Val Accuracy = 97.0
# epoch 100
# 124.92785334587097 seconds
# loss 329.08628499507904
# Accuracy = 99.86077117919922
# 4.991433620452881 seconds
# val loss 37.301029443740845
#  Val Accuracy = 96.75
# epoch 101
# 125.0106430053711 seconds
# loss 329.08366560935974
# Accuracy = 99.86077117919922
# 4.9210121631622314 seconds
# val loss 37.330689668655396
#  Val Accuracy = 96.5
# epoch 102
# 124.99967360496521 seconds
# loss 329.09123492240906
# Accuracy = 99.86077117919922
# 4.9663965702056885 seconds
# val loss 37.33674204349518
#  Val Accuracy = 96.5
# epoch 103
# 125.14826583862305 seconds
# loss 329.1869719028473
# Accuracy = 99.86077117919922
# 4.946141719818115 seconds
# val loss 37.35751736164093
#  Val Accuracy = 97.0
# epoch 104
# 125.02167439460754 seconds
# loss 329.0957428216934
# Accuracy = 99.86077117919922
# 4.969995021820068 seconds
# val loss 37.272292494773865
#  Val Accuracy = 97.25
# epoch 105
# 125.06204628944397 seconds
# loss 329.1249407529831
# Accuracy = 99.86077117919922
# 4.947099208831787 seconds
# val loss 37.17219614982605
#  Val Accuracy = 97.75
# epoch 106
# 125.07208371162415 seconds
# loss 329.1036946773529
# Accuracy = 99.86077117919922
# 4.98100733757019 seconds
# val loss 37.31077301502228
#  Val Accuracy = 96.75
# epoch 107
# 124.97707962989807 seconds
# loss 329.1018534898758
# Accuracy = 99.86077117919922
# 4.945446968078613 seconds
# val loss 37.335057735443115
#  Val Accuracy = 96.75
# epoch 108
# 125.02984023094177 seconds
# loss 329.08550798892975
# Accuracy = 99.86077117919922
# 5.0291430950164795 seconds
# val loss 37.38625407218933
#  Val Accuracy = 96.5
# epoch 109
# 124.88665127754211 seconds
# loss 329.10214161872864
# Accuracy = 99.86077117919922
# 4.974252462387085 seconds
# val loss 37.30972158908844
#  Val Accuracy = 96.75
# epoch 110
# 124.92672514915466 seconds
# loss 329.0883206129074
# Accuracy = 99.86077117919922
# 4.97507119178772 seconds
# val loss 37.41277778148651
#  Val Accuracy = 96.5
# epoch 111
# 125.05287265777588 seconds
# loss 329.08748626708984
# Accuracy = 99.86077117919922
# 4.913894891738892 seconds
# val loss 37.36355185508728
#  Val Accuracy = 96.75
# epoch 112
# 125.04884600639343 seconds
# loss 329.11318492889404
# Accuracy = 99.83292388916016
# 5.000507116317749 seconds
# val loss 37.45466601848602
#  Val Accuracy = 96.25
# epoch 113
# 125.10627627372742 seconds
# loss 329.08621084690094
# Accuracy = 99.86077117919922
# 4.983164548873901 seconds
# val loss 37.41072654724121
#  Val Accuracy = 96.25
# epoch 114
# 124.99911618232727 seconds
# loss 329.1214065551758
# Accuracy = 99.86077117919922
# 4.964713096618652 seconds
# val loss 37.409894824028015
#  Val Accuracy = 96.25
# epoch 115
# 125.12015295028687 seconds
# loss 329.0976130962372
# Accuracy = 99.86077117919922
# 4.969318389892578 seconds
# val loss 37.191752672195435
#  Val Accuracy = 97.5
# epoch 116
# 125.00625514984131 seconds
# loss 329.0984208583832
# Accuracy = 99.86077117919922
# 4.953250169754028 seconds
# val loss 37.36382532119751
#  Val Accuracy = 96.25
# epoch 117
# 124.96448755264282 seconds
# loss 329.08731389045715
# Accuracy = 99.86077117919922
# 4.973633766174316 seconds
# val loss 37.27276682853699
#  Val Accuracy = 97.5
# epoch 118
# 124.98472094535828 seconds
# loss 329.0819321870804
# Accuracy = 99.86077117919922
# 4.953563928604126 seconds
# val loss 37.327062368392944
#  Val Accuracy = 96.75
# epoch 119
# 125.04279041290283 seconds
# loss 329.0949184894562
# Accuracy = 99.86077117919922
# 4.952699184417725 seconds
# val loss 37.11963379383087
#  Val Accuracy = 98.25
# new best acc
# epoch 120
# 125.08174014091492 seconds
# loss 329.10738372802734
# Accuracy = 99.86077117919922
# 5.001362562179565 seconds
# val loss 37.30751192569733
#  Val Accuracy = 96.75
# epoch 121
# 124.88666844367981 seconds
# loss 329.0923048257828
# Accuracy = 99.86077117919922
# 4.945466756820679 seconds
# val loss 37.34783232212067
#  Val Accuracy = 96.75
# epoch 122
# 124.94329738616943 seconds
# loss 329.0864849090576
# Accuracy = 99.86077117919922
# 4.976037263870239 seconds
# val loss 37.22806203365326
#  Val Accuracy = 97.5
# epoch 123
# 125.0049479007721 seconds
# loss 329.08933365345
# Accuracy = 99.86077117919922
# 5.187222480773926 seconds
# val loss 37.242005586624146
#  Val Accuracy = 97.0
# epoch 124
# 124.86859440803528 seconds
# loss 329.0804592370987
# Accuracy = 99.86077117919922
# 4.9775872230529785 seconds
# val loss 37.24899995326996
#  Val Accuracy = 97.25
# epoch 125
# 125.03944635391235 seconds
# loss 329.163929104805
# Accuracy = 99.86077117919922
# 4.991037607192993 seconds
# val loss 37.188822746276855
#  Val Accuracy = 97.5
# epoch 126
# 124.92279052734375 seconds
# loss 329.08543276786804
# Accuracy = 99.86077117919922
# 5.086031675338745 seconds
# val loss 37.294771671295166
#  Val Accuracy = 97.0
# epoch 127
# 125.05014538764954 seconds
# loss 329.08261919021606
# Accuracy = 99.86077117919922
# 4.959853887557983 seconds
# val loss 37.36140775680542
#  Val Accuracy = 96.75
# epoch 128
# 124.90135550498962 seconds
# loss 329.07945489883423
# Accuracy = 99.86077117919922
# 4.965047836303711 seconds
# val loss 37.19221556186676
#  Val Accuracy = 97.5
# epoch 129
# 124.8710424900055 seconds
# loss 329.07831597328186
# Accuracy = 99.86077117919922
# 4.978341817855835 seconds
# val loss 37.28006029129028
#  Val Accuracy = 97.0
# epoch 130
# 124.91971111297607 seconds
# loss 329.08075535297394
# Accuracy = 99.86077117919922
# 4.959579944610596 seconds
# val loss 37.326740860939026
#  Val Accuracy = 96.75
# epoch 131
# 124.90823125839233 seconds
# loss 329.0860698223114
# Accuracy = 99.86077117919922
# 4.992842197418213 seconds
# val loss 37.299750089645386
#  Val Accuracy = 96.75
# epoch 132
# 124.83656859397888 seconds
# loss 329.10058188438416
# Accuracy = 99.86077117919922
# 4.966050624847412 seconds
# val loss 37.267966866493225
#  Val Accuracy = 97.0
# epoch 133
# 124.87558150291443 seconds
# loss 329.08185970783234
# Accuracy = 99.86077117919922
# 4.938533306121826 seconds
# val loss 37.30250287055969
#  Val Accuracy = 96.5
# epoch 134
# 124.96059274673462 seconds
# loss 329.09172666072845
# Accuracy = 99.86077117919922
# 4.9659364223480225 seconds
# val loss 37.33398675918579
#  Val Accuracy = 97.0
# epoch 135
# 124.91183304786682 seconds
# loss 329.0860902070999
# Accuracy = 99.86077117919922
# 4.962749481201172 seconds
# val loss 37.24371671676636
#  Val Accuracy = 97.5
# epoch 136
# 124.96526193618774 seconds
# loss 329.2230581045151
# Accuracy = 99.83292388916016
# 4.9652910232543945 seconds
# val loss 37.30120813846588
#  Val Accuracy = 96.75
# epoch 137
# 125.10700917243958 seconds
# loss 329.0917395353317
# Accuracy = 99.86077117919922
# 4.9669342041015625 seconds
# val loss 37.31005573272705
#  Val Accuracy = 97.0
# epoch 138
# 124.991783618927 seconds
# loss 329.0872620344162
# Accuracy = 99.86077117919922
# 4.962996482849121 seconds
# val loss 37.306182503700256
#  Val Accuracy = 96.75
# epoch 139
# 125.19744658470154 seconds
# loss 329.1031084060669
# Accuracy = 99.86077117919922
# 4.986515283584595 seconds
# val loss 37.26598083972931
#  Val Accuracy = 97.25
# epoch 140
# 125.04968762397766 seconds
# loss 329.08986163139343
# Accuracy = 99.86077117919922
# 4.985978126525879 seconds
# val loss 37.14620804786682
#  Val Accuracy = 97.5
# epoch 141
# 124.98332214355469 seconds
# loss 329.086590886116
# Accuracy = 99.86077117919922
# 4.9686243534088135 seconds
# val loss 37.42053830623627
#  Val Accuracy = 96.5
# epoch 142
# 125.1143958568573 seconds
# loss 329.08195972442627
# Accuracy = 99.86077117919922
# 5.001222848892212 seconds
# val loss 37.24829852581024
#  Val Accuracy = 97.25
# epoch 143
# 125.04446959495544 seconds
# loss 329.07960760593414
# Accuracy = 99.86077117919922
# 5.01228404045105 seconds
# val loss 37.283992409706116
#  Val Accuracy = 97.0
# epoch 144
# 125.01123785972595 seconds
# loss 329.0844053030014
# Accuracy = 99.86077117919922
# 4.965184450149536 seconds
# val loss 37.2848881483078
#  Val Accuracy = 97.25
# epoch 145
# 125.03773546218872 seconds
# loss 329.0821968317032
# Accuracy = 99.86077117919922
# 5.000322341918945 seconds
# val loss 37.24721693992615
#  Val Accuracy = 97.25
# epoch 146
# 125.03214597702026 seconds
# loss 329.0810400247574
# Accuracy = 99.86077117919922
# 4.944753170013428 seconds
# val loss 37.34796607494354
#  Val Accuracy = 96.75
# epoch 147
# 125.0485143661499 seconds
# loss 329.10241878032684
# Accuracy = 99.86077117919922
# 4.945276498794556 seconds
# val loss 37.24454212188721
#  Val Accuracy = 97.0
# epoch 148
# 125.18911933898926 seconds
# loss 329.08732652664185
# Accuracy = 99.86077117919922
# 4.9615631103515625 seconds
# val loss 37.259687423706055
#  Val Accuracy = 97.25
# epoch 149
# 125.08385300636292 seconds
# loss 329.0823094844818
# Accuracy = 99.86077117919922
# 4.918339490890503 seconds
# val loss 37.29489827156067
#  Val Accuracy = 97.0
# epoch 150
# 125.05339002609253 seconds
# loss 329.0958718061447
# Accuracy = 99.86077117919922
# 4.986645936965942 seconds
# val loss 37.298320174217224
#  Val Accuracy = 96.75
# epoch 151
# 125.07381677627563 seconds
# loss 329.08359384536743
# Accuracy = 99.86077117919922
# 5.0447046756744385 seconds
# val loss 37.376354336738586
#  Val Accuracy = 96.5
# epoch 152
# 124.9929187297821 seconds
# loss 329.1317763328552
# Accuracy = 99.83292388916016
# 4.9395811557769775 seconds
# val loss 37.382150530815125
#  Val Accuracy = 96.5
# epoch 153
# 124.95819854736328 seconds
# loss 329.0868821144104
# Accuracy = 99.86077117919922
# 4.968445301055908 seconds
# val loss 37.296992778778076
#  Val Accuracy = 96.75
# epoch 154
# 124.9989902973175 seconds
# loss 329.08476996421814
# Accuracy = 99.86077117919922
# 4.963385105133057 seconds
# val loss 37.340808033943176
#  Val Accuracy = 97.0
# epoch 155
# 125.01817035675049 seconds
# loss 329.0819420814514
# Accuracy = 99.86077117919922
# 4.961409568786621 seconds
# val loss 37.2311989068985
#  Val Accuracy = 97.0
# epoch 156
# 125.10261535644531 seconds
# loss 329.0795431137085
# Accuracy = 99.86077117919922
# 4.970492839813232 seconds
# val loss 37.24126863479614
#  Val Accuracy = 97.0
# epoch 157
# 124.93638849258423 seconds
# loss 329.0821096897125
# Accuracy = 99.86077117919922
# 4.9835991859436035 seconds
# val loss 37.237778425216675
#  Val Accuracy = 97.5
# epoch 158
# 125.06936717033386 seconds
# loss 329.09038984775543
# Accuracy = 99.86077117919922
# 4.98600172996521 seconds
# val loss 37.340816378593445
#  Val Accuracy = 96.75
# epoch 159
# 125.03593802452087 seconds
# loss 329.08296024799347
# Accuracy = 99.86077117919922
# 4.933454513549805 seconds
# val loss 37.319302558898926
#  Val Accuracy = 96.5
# epoch 160
# 125.08521842956543 seconds
# loss 329.0874937772751
# Accuracy = 99.86077117919922
# 4.982053279876709 seconds
# val loss 37.305957198143005
#  Val Accuracy = 96.75
# epoch 161
# 125.11851191520691 seconds
# loss 329.08029901981354
# Accuracy = 99.86077117919922
# 5.007177829742432 seconds
# val loss 37.270819544792175
#  Val Accuracy = 96.75
# epoch 162
# 125.1031002998352 seconds
# loss 329.07759940624237
# Accuracy = 99.86077117919922
# 4.973009824752808 seconds
# val loss 37.273685574531555
#  Val Accuracy = 96.75
# epoch 163
# 125.0202465057373 seconds
# loss 329.07840836048126
# Accuracy = 99.86077117919922
# 4.963660955429077 seconds
# val loss 37.16258120536804
#  Val Accuracy = 97.75
# epoch 164
# 124.99249458312988 seconds
# loss 329.077116727829
# Accuracy = 99.86077117919922
# 5.011881113052368 seconds
# val loss 37.21575605869293
#  Val Accuracy = 97.25
# epoch 165
# 125.0722279548645 seconds
# loss 329.10165643692017
# Accuracy = 99.86077117919922
# 4.976027011871338 seconds
# val loss 37.32250905036926
#  Val Accuracy = 96.75
# epoch 166
# 125.3165237903595 seconds
# loss 329.0855642557144
# Accuracy = 99.86077117919922
# 4.989558458328247 seconds
# val loss 37.25381124019623
#  Val Accuracy = 97.25
# epoch 167
# 125.3104338645935 seconds
# loss 329.08035576343536
# Accuracy = 99.86077117919922
# 4.993080377578735 seconds
# val loss 37.25434958934784
#  Val Accuracy = 97.0
# epoch 168
# 125.0236291885376 seconds
# loss 329.0854505300522
# Accuracy = 99.86077117919922
# 4.951791048049927 seconds
# val loss 37.22281610965729
#  Val Accuracy = 97.25
# epoch 169
# 125.10153579711914 seconds
# loss 329.0838212966919
# Accuracy = 99.86077117919922
# 4.97162652015686 seconds
# val loss 37.231348514556885
#  Val Accuracy = 97.0
# epoch 170
# 124.98461985588074 seconds
# loss 329.07825779914856
# Accuracy = 99.86077117919922
# 4.989012241363525 seconds
# val loss 37.366843581199646
#  Val Accuracy = 96.5
# epoch 171
# 124.96996474266052 seconds
# loss 329.0867519378662
# Accuracy = 99.86077117919922
# 4.9532790184021 seconds
# val loss 37.23429608345032
#  Val Accuracy = 97.0
# epoch 172
# 125.0443742275238 seconds
# loss 329.080415725708
# Accuracy = 99.86077117919922
# 4.929997444152832 seconds
# val loss 37.24791753292084
#  Val Accuracy = 97.25
# epoch 173
# 124.95571875572205 seconds
# loss 329.08122658729553
# Accuracy = 99.86077117919922
# 4.953323841094971 seconds
# val loss 37.31212878227234
#  Val Accuracy = 96.75
# epoch 174
# 125.0335693359375 seconds
# loss 329.0806175470352
# Accuracy = 99.86077117919922
# 4.958551406860352 seconds
# val loss 37.3789644241333
#  Val Accuracy = 96.5
# epoch 175
# 125.04514932632446 seconds
# loss 329.0805604457855
# Accuracy = 99.86077117919922
# 4.981278657913208 seconds
# val loss 37.34991765022278
#  Val Accuracy = 96.25
# epoch 176
# 125.02984523773193 seconds
# loss 329.079038977623
# Accuracy = 99.86077117919922
# 4.998680114746094 seconds
# val loss 37.38290739059448
#  Val Accuracy = 96.5
# epoch 177
# 124.98496460914612 seconds
# loss 329.12482011318207
# Accuracy = 99.86077117919922
# 5.039065837860107 seconds
# val loss 37.285401821136475
#  Val Accuracy = 96.75
# epoch 178
# 124.94687461853027 seconds
# loss 329.09897351264954
# Accuracy = 99.86077117919922
# 4.960764646530151 seconds
# val loss 37.28918254375458
#  Val Accuracy = 97.0
# epoch 179
# 124.982248544693 seconds
# loss 329.09633445739746
# Accuracy = 99.86077117919922
# 4.948131322860718 seconds
# val loss 37.41515564918518
#  Val Accuracy = 96.5
# epoch 180
# 125.00831818580627 seconds
# loss 329.08139300346375
# Accuracy = 99.86077117919922
# 4.980798959732056 seconds
# val loss 37.402860164642334
#  Val Accuracy = 96.75
# epoch 181
# 125.00449633598328 seconds
# loss 329.08921241760254
# Accuracy = 99.86077117919922
# 4.95015287399292 seconds
# val loss 37.22243916988373
#  Val Accuracy = 97.0
# epoch 182
# 124.90094590187073 seconds
# loss 329.0813834667206
# Accuracy = 99.86077117919922
# 4.967849969863892 seconds
# val loss 37.29356050491333
#  Val Accuracy = 97.0
# epoch 183
# 125.04849624633789 seconds
# loss 329.0775467157364
# Accuracy = 99.86077117919922
# 4.959075450897217 seconds
# val loss 37.34260952472687
#  Val Accuracy = 96.75
# epoch 184
# 125.17695474624634 seconds
# loss 329.0779536962509
# Accuracy = 99.86077117919922
# 4.99933385848999 seconds
# val loss 37.28224456310272
#  Val Accuracy = 96.75
# epoch 185
# 125.0997862815857 seconds
# loss 329.07536947727203
# Accuracy = 99.86077117919922
# 4.9697184562683105 seconds
# val loss 37.23821425437927
#  Val Accuracy = 97.25
# epoch 186
# 125.1390860080719 seconds
# loss 329.08686459064484
# Accuracy = 99.86077117919922
# 5.0115838050842285 seconds
# val loss 37.28145730495453
#  Val Accuracy = 97.0
# epoch 187
# 125.11154198646545 seconds
# loss 329.0775258541107
# Accuracy = 99.86077117919922
# 4.989972829818726 seconds
# val loss 37.1832480430603
#  Val Accuracy = 97.75
# epoch 188
# 125.06916356086731 seconds
# loss 329.0893642902374
# Accuracy = 99.86077117919922
# 4.9856181144714355 seconds
# val loss 37.34831953048706
#  Val Accuracy = 96.5
# epoch 189
# 125.02294158935547 seconds
# loss 329.1025719642639
# Accuracy = 99.86077117919922
# 5.007603645324707 seconds
# val loss 37.356563448905945
#  Val Accuracy = 96.5
# epoch 190
# 125.10451817512512 seconds
# loss 329.0799572467804
# Accuracy = 99.86077117919922
# 4.966608762741089 seconds
# val loss 37.41587436199188
#  Val Accuracy = 96.25
# epoch 191
# 124.88324165344238 seconds
# loss 329.0802073478699
# Accuracy = 99.86077117919922
# 4.967984437942505 seconds
# val loss 37.239684104919434
#  Val Accuracy = 97.0
# epoch 192
# 124.85366487503052 seconds
# loss 329.07580602169037
# Accuracy = 99.86077117919922
# 4.942176342010498 seconds
# val loss 37.25030493736267
#  Val Accuracy = 97.25
# epoch 193
# 124.95434951782227 seconds
# loss 329.08687150478363
# Accuracy = 99.86077117919922
# 4.956759691238403 seconds
# val loss 37.29763662815094
#  Val Accuracy = 96.75
# epoch 194
# 124.91045188903809 seconds
# loss 329.08227002620697
# Accuracy = 99.86077117919922
# 4.936764478683472 seconds
# val loss 37.31362199783325
#  Val Accuracy = 96.75
# epoch 195
# 124.85209226608276 seconds
# loss 329.091988325119
# Accuracy = 99.86077117919922
# 4.9625043869018555 seconds
# val loss 37.26519048213959
#  Val Accuracy = 97.25
# epoch 196
# 124.95640468597412 seconds
# loss 329.0802811384201
# Accuracy = 99.86077117919922
# 4.942582368850708 seconds
# val loss 37.41492688655853
#  Val Accuracy = 96.25
# epoch 197
# 124.92557406425476 seconds
# loss 329.10033774375916
# Accuracy = 99.86077117919922
# 4.97141695022583 seconds
# val loss 37.387977719306946
#  Val Accuracy = 96.5
# epoch 198
# 125.00296473503113 seconds
# loss 329.0823789834976
# Accuracy = 99.86077117919922
# 4.976029872894287 seconds
# val loss 37.41949737071991
#  Val Accuracy = 96.25
# epoch 199
# 124.9445104598999 seconds
# loss 329.08058404922485
# Accuracy = 99.86077117919922
# 4.959091663360596 seconds
# val loss 37.41206610202789
#  Val Accuracy = 96.5
# epoch 200
# 125.04580640792847 seconds
# loss 329.103884100914
# Accuracy = 99.86077117919922
# 4.962832450866699 seconds
# val loss 37.241331815719604
#  Val Accuracy = 97.25
# epoch 201
# 124.8688554763794 seconds
# loss 329.08947920799255
# Accuracy = 99.86077117919922
# 4.933924198150635 seconds
# val loss 37.40526795387268
#  Val Accuracy = 96.5
# epoch 202
# 124.93356966972351 seconds
# loss 329.0766314268112
# Accuracy = 99.86077117919922
# 5.048012971878052 seconds
# val loss 37.266368985176086
#  Val Accuracy = 97.25
# epoch 203
# 125.26144337654114 seconds
# loss 329.0785890817642
# Accuracy = 99.86077117919922
# 4.9792656898498535 seconds
# val loss 37.177966594696045
#  Val Accuracy = 97.5
# epoch 204
# 124.96230268478394 seconds
# loss 329.10643923282623
# Accuracy = 99.86077117919922
# 4.992294788360596 seconds
# val loss 37.360573172569275
#  Val Accuracy = 96.75
# epoch 205
# 125.06394028663635 seconds
# loss 329.0781316757202
# Accuracy = 99.86077117919922
# 5.0094499588012695 seconds
# val loss 37.2673978805542
#  Val Accuracy = 97.0
# epoch 206
# 124.8926796913147 seconds
# loss 329.0766267776489
# Accuracy = 99.86077117919922
# 4.980815172195435 seconds
# val loss 37.29831397533417
#  Val Accuracy = 97.0
# epoch 207
# 124.96163988113403 seconds
# loss 329.08057820796967
# Accuracy = 99.86077117919922
# 4.976065158843994 seconds
# val loss 37.32712244987488
#  Val Accuracy = 97.0
# epoch 208
# 124.97583603858948 seconds
# loss 329.07776856422424
# Accuracy = 99.86077117919922
# 4.990811824798584 seconds
# val loss 37.31366717815399
#  Val Accuracy = 96.75
# epoch 209
# 124.97536420822144 seconds
# loss 329.08308374881744
# Accuracy = 99.86077117919922
# 5.018997669219971 seconds
# val loss 37.27308511734009
#  Val Accuracy = 97.25
# epoch 210
# 125.01640844345093 seconds
# loss 329.0745508670807
# Accuracy = 99.86077117919922
# 5.066917419433594 seconds
# val loss 37.285112500190735
#  Val Accuracy = 97.0
# epoch 211
# 124.95012283325195 seconds
# loss 329.07780957221985
# Accuracy = 99.86077117919922
# 4.984710693359375 seconds
# val loss 37.346218943595886
#  Val Accuracy = 96.75
# epoch 212
# 124.85607957839966 seconds
# loss 329.07545375823975
# Accuracy = 99.86077117919922
# 4.955513954162598 seconds
# val loss 37.205830812454224
#  Val Accuracy = 97.75
# epoch 213
# 124.99281239509583 seconds
# loss 329.07495045661926
# Accuracy = 99.86077117919922
# 4.977237939834595 seconds
# val loss 37.26233649253845
#  Val Accuracy = 97.0
# epoch 214
# 124.91758513450623 seconds
# loss 329.0804818868637
# Accuracy = 99.86077117919922
# 4.953759670257568 seconds
# val loss 37.25933766365051
#  Val Accuracy = 97.25
# epoch 215
# 124.97108125686646 seconds
# loss 329.0789612531662
# Accuracy = 99.86077117919922
# 4.9836266040802 seconds
# val loss 37.24029326438904
#  Val Accuracy = 97.0
# epoch 216
# 124.92407560348511 seconds
# loss 329.0826724767685
# Accuracy = 99.86077117919922
# 4.968549728393555 seconds
# val loss 37.28967571258545
#  Val Accuracy = 97.0
# epoch 217
# 124.82162666320801 seconds
# loss 329.07555305957794
# Accuracy = 99.86077117919922
# 4.951770782470703 seconds
# val loss 37.26885771751404
#  Val Accuracy = 97.0
# epoch 218
# 125.0079665184021 seconds
# loss 329.07586085796356
# Accuracy = 99.86077117919922
# 4.97265100479126 seconds
# val loss 37.28092885017395
#  Val Accuracy = 97.25
# epoch 219
# 124.93016362190247 seconds
# loss 329.0752432346344
# Accuracy = 99.86077117919922
# 5.0073182582855225 seconds
# val loss 37.33910953998566
#  Val Accuracy = 96.75
# epoch 220
# 125.21307921409607 seconds
# loss 329.0749272108078
# Accuracy = 99.86077117919922
# 4.981565713882446 seconds
# val loss 37.28850495815277
#  Val Accuracy = 97.0
# epoch 221
# 124.97550296783447 seconds
# loss 329.07892668247223
# Accuracy = 99.86077117919922
# 4.945779800415039 seconds
# val loss 37.35255229473114
#  Val Accuracy = 96.25
# epoch 222
# 125.1080424785614 seconds
# loss 329.0789135694504
# Accuracy = 99.86077117919922
# 4.961792945861816 seconds
# val loss 37.32486855983734
#  Val Accuracy = 97.25
# epoch 223
# 124.98876929283142 seconds
# loss 329.07867753505707
# Accuracy = 99.86077117919922
# 5.05177116394043 seconds
# val loss 37.39313316345215
#  Val Accuracy = 96.75
# epoch 224
# 124.97673320770264 seconds
# loss 329.0761971473694
# Accuracy = 99.86077117919922
# 4.964626789093018 seconds
# val loss 37.33771216869354
#  Val Accuracy = 96.75
# epoch 225
# 124.9632740020752 seconds
# loss 329.0744720697403
# Accuracy = 99.86077117919922
# 4.932104587554932 seconds
# val loss 37.39525496959686
#  Val Accuracy = 96.5
# epoch 226
# 124.9733362197876 seconds
# loss 329.07622039318085
# Accuracy = 99.86077117919922
# 4.9672417640686035 seconds
# val loss 37.2386029958725
#  Val Accuracy = 97.5
# epoch 227
# 124.97979068756104 seconds
# loss 329.0830855369568
# Accuracy = 99.86077117919922
# 4.956503629684448 seconds
# val loss 37.23539888858795
#  Val Accuracy = 97.25
# epoch 228
# 124.9660439491272 seconds
# loss 329.08220624923706
# Accuracy = 99.86077117919922
# 4.970072507858276 seconds
# val loss 37.323688983917236
#  Val Accuracy = 97.0
# epoch 229
# 124.9783787727356 seconds
# loss 329.0758875608444
# Accuracy = 99.86077117919922
# 4.930950880050659 seconds
# val loss 37.49772262573242
#  Val Accuracy = 96.5
# epoch 230
# 125.01281690597534 seconds
# loss 329.08171486854553
# Accuracy = 99.86077117919922
# 4.9824512004852295 seconds
# val loss 37.309781312942505
#  Val Accuracy = 96.75
# epoch 231
# 124.94274997711182 seconds
# loss 329.0776569843292
# Accuracy = 99.86077117919922
# 4.968188762664795 seconds
# val loss 37.33630299568176
#  Val Accuracy = 96.75
# epoch 232
# 125.0174949169159 seconds
# loss 329.0776010751724
# Accuracy = 99.86077117919922
# 4.971182107925415 seconds
# val loss 37.230752825737
#  Val Accuracy = 97.5
# epoch 233
# 125.06162452697754 seconds
# loss 329.0747652053833
# Accuracy = 99.86077117919922
# 4.939821481704712 seconds
# val loss 37.1744327545166
#  Val Accuracy = 97.75
# epoch 234
# 125.06213092803955 seconds
# loss 329.0750563144684
# Accuracy = 99.86077117919922
# 4.967033863067627 seconds
# val loss 37.34343433380127
#  Val Accuracy = 96.75
# epoch 235
# 124.97671580314636 seconds
# loss 329.07975685596466
# Accuracy = 99.86077117919922
# 5.042387008666992 seconds
# val loss 37.26818895339966
#  Val Accuracy = 97.0
# epoch 236
# 125.02784657478333 seconds
# loss 329.0759382247925
# Accuracy = 99.86077117919922
# 4.938478708267212 seconds
# val loss 37.223127007484436
#  Val Accuracy = 97.5
# epoch 237
# 124.98100757598877 seconds
# loss 329.07538521289825
# Accuracy = 99.86077117919922
# 4.973785161972046 seconds
# val loss 37.233131527900696
#  Val Accuracy = 97.5
# epoch 238
# 125.11393594741821 seconds
# loss 329.10073947906494
# Accuracy = 99.86077117919922
# 4.978749752044678 seconds
# val loss 37.38207483291626
#  Val Accuracy = 96.5
# epoch 239
# 125.1147723197937 seconds
# loss 329.07673382759094
# Accuracy = 99.86077117919922
# 4.976105451583862 seconds
# val loss 37.33871805667877
#  Val Accuracy = 97.0
# epoch 240
# 124.98804807662964 seconds
# loss 329.08012664318085
# Accuracy = 99.86077117919922
# 4.956181526184082 seconds
# val loss 37.32841444015503
#  Val Accuracy = 97.0
# epoch 241
# 125.11109209060669 seconds
# loss 329.0843472480774
# Accuracy = 99.86077117919922
# 5.0012290477752686 seconds
# val loss 37.24575877189636
#  Val Accuracy = 97.25
# epoch 242
# 125.03465938568115 seconds
# loss 329.0800964832306
# Accuracy = 99.86077117919922
# 5.004957914352417 seconds
# val loss 37.307623982429504
#  Val Accuracy = 96.5
# epoch 243
# 125.12750339508057 seconds
# loss 329.0748188495636
# Accuracy = 99.86077117919922
# 4.991899013519287 seconds
# val loss 37.34104287624359
#  Val Accuracy = 97.0
# epoch 244
# 125.15740919113159 seconds
# loss 329.0776025056839
# Accuracy = 99.86077117919922
# 4.933871269226074 seconds
# val loss 37.30657684803009
#  Val Accuracy = 97.25
# epoch 245
# 125.08099222183228 seconds
# loss 329.0757786035538
# Accuracy = 99.86077117919922
# 4.9747796058654785 seconds
# val loss 37.34684634208679
#  Val Accuracy = 97.0
# epoch 246
# 124.99482250213623 seconds
# loss 329.0753951072693
# Accuracy = 99.86077117919922
# 4.977640151977539 seconds
# val loss 37.2980180978775
#  Val Accuracy = 96.75
# epoch 247
# 125.02531266212463 seconds
# loss 329.0747559070587
# Accuracy = 99.86077117919922
# 4.9650397300720215 seconds
# val loss 37.29302179813385
#  Val Accuracy = 96.75
# epoch 248
# 125.14025855064392 seconds
# loss 329.0768200159073
# Accuracy = 99.86077117919922
# 5.049800634384155 seconds
# val loss 37.318042516708374
#  Val Accuracy = 97.0
# epoch 249
# 124.95514011383057 seconds
# loss 329.07782208919525
# Accuracy = 99.86077117919922
# 4.974619150161743 seconds
# val loss 37.160818219184875
#  Val Accuracy = 97.75
# epoch 250
# 125.00600814819336 seconds
# loss 329.08162689208984
# Accuracy = 99.86077117919922
# 4.982257127761841 seconds
# val loss 37.40322983264923
#  Val Accuracy = 96.75
# epoch 251
# 125.06303119659424 seconds
# loss 329.0754095315933
# Accuracy = 99.86077117919922
# 4.977970600128174 seconds
# val loss 37.275304436683655
#  Val Accuracy = 97.0
# epoch 252
# 125.0811505317688 seconds
# loss 329.0742537975311
# Accuracy = 99.86077117919922
# 4.955883026123047 seconds
# val loss 37.394601583480835
#  Val Accuracy = 96.75
# epoch 253
# 125.0745677947998 seconds
# loss 329.075274348259
# Accuracy = 99.86077117919922
# 4.992709636688232 seconds
# val loss 37.28733515739441
#  Val Accuracy = 97.0
# epoch 254
# 125.04703783988953 seconds
# loss 329.07537746429443
# Accuracy = 99.86077117919922
# 4.967808961868286 seconds
# val loss 37.36591374874115
#  Val Accuracy = 96.75
# epoch 255
# 125.14632940292358 seconds
# loss 329.0782525539398
# Accuracy = 99.86077117919922
# 4.9693169593811035 seconds
# val loss 37.32526743412018
#  Val Accuracy = 96.75
# epoch 256
# 125.09533166885376 seconds
# loss 329.075776219368
# Accuracy = 99.86077117919922
# 4.93575644493103 seconds
# val loss 37.39873480796814
#  Val Accuracy = 96.25
# epoch 257
# 125.1069643497467 seconds
# loss 329.07449531555176
# Accuracy = 99.86077117919922
# 4.972877264022827 seconds
# val loss 37.41421568393707
#  Val Accuracy = 96.25
# epoch 258
# 125.10705900192261 seconds
# loss 329.07459104061127
# Accuracy = 99.86077117919922
# 4.970384120941162 seconds
# val loss 37.27410566806793
#  Val Accuracy = 97.0
# epoch 259
# 125.02758455276489 seconds
# loss 329.0757454633713
# Accuracy = 99.86077117919922
# 4.9719557762146 seconds
# val loss 37.36591112613678
#  Val Accuracy = 96.5
# epoch 260
# 125.10018277168274 seconds
# loss 329.07373547554016
# Accuracy = 99.86077117919922
# 4.984511852264404 seconds
# val loss 37.27429008483887
#  Val Accuracy = 97.0
# epoch 261
# 125.1017382144928 seconds
# loss 329.0736652612686
# Accuracy = 99.86077117919922
# 5.052800416946411 seconds
# val loss 37.317437291145325
#  Val Accuracy = 96.75
# epoch 262
# 125.10907077789307 seconds
# loss 329.0738513469696
# Accuracy = 99.86077117919922
# 4.988869667053223 seconds
# val loss 37.35615646839142
#  Val Accuracy = 97.0
# epoch 263
# 125.00698566436768 seconds
# loss 329.075452208519
# Accuracy = 99.86077117919922
# 4.945990562438965 seconds
# val loss 37.268744111061096
#  Val Accuracy = 97.0
# epoch 264
# 125.06456327438354 seconds
# loss 329.0795636177063
# Accuracy = 99.86077117919922
# 4.96426248550415 seconds
# val loss 37.34808146953583
#  Val Accuracy = 96.5
# epoch 265
# 125.022629737854 seconds
# loss 329.0753254890442
# Accuracy = 99.86077117919922
# 4.969656705856323 seconds
# val loss 37.339601278305054
#  Val Accuracy = 97.0
# epoch 266
# 124.98770809173584 seconds
# loss 329.07665050029755
# Accuracy = 99.86077117919922
# 4.971561670303345 seconds
# val loss 37.25523114204407
#  Val Accuracy = 96.75
# epoch 267
# 125.06964063644409 seconds
# loss 329.07478630542755
# Accuracy = 99.86077117919922
# 4.996947288513184 seconds
# val loss 37.33367359638214
#  Val Accuracy = 96.75
# epoch 268
# 125.01054787635803 seconds
# loss 329.07482647895813
# Accuracy = 99.86077117919922
# 4.973286390304565 seconds
# val loss 37.297046422958374
#  Val Accuracy = 97.0
# epoch 269
# 125.00703835487366 seconds
# loss 329.0735676288605
# Accuracy = 99.86077117919922
# 4.946158409118652 seconds
# val loss 37.18711590766907
#  Val Accuracy = 97.5
# epoch 270
# 125.01701974868774 seconds
# loss 329.08563339710236
# Accuracy = 99.86077117919922
# 4.986932277679443 seconds
# val loss 37.12652289867401
#  Val Accuracy = 97.75
# epoch 271
# 125.03576707839966 seconds
# loss 329.07472693920135
# Accuracy = 99.86077117919922
# 4.9629082679748535 seconds
# val loss 37.3476425409317
#  Val Accuracy = 96.5
# epoch 272
# 124.96655201911926 seconds
# loss 329.08041846752167
# Accuracy = 99.86077117919922
# 4.98758602142334 seconds
# val loss 37.41129422187805
#  Val Accuracy = 96.25
# epoch 273
# 124.89719271659851 seconds
# loss 329.0745952129364
# Accuracy = 99.86077117919922
# 5.031876087188721 seconds
# val loss 37.318119525909424
#  Val Accuracy = 97.0
# epoch 274
# 124.90981864929199 seconds
# loss 329.07736802101135
# Accuracy = 99.86077117919922
# 5.029513359069824 seconds
# val loss 37.38934409618378
#  Val Accuracy = 96.5
# epoch 275
# 125.00788855552673 seconds
# loss 329.07548451423645
# Accuracy = 99.86077117919922
# 4.99049973487854 seconds
# val loss 37.30362892150879
#  Val Accuracy = 97.25
# epoch 276
# 125.02259826660156 seconds
# loss 329.0739550590515
# Accuracy = 99.86077117919922
# 5.021438121795654 seconds
# val loss 37.15771234035492
#  Val Accuracy = 97.5
# epoch 277
# 125.12321519851685 seconds
# loss 329.07376849651337
# Accuracy = 99.86077117919922
# 5.002587556838989 seconds
# val loss 37.18243432044983
#  Val Accuracy = 97.75
# epoch 278
# 125.05944180488586 seconds
# loss 329.07632851600647
# Accuracy = 99.86077117919922
# 4.969421148300171 seconds
# val loss 37.29240036010742
#  Val Accuracy = 97.0
# epoch 279
# 125.07789921760559 seconds
# loss 329.0738613605499
# Accuracy = 99.86077117919922
# 4.979047775268555 seconds
# val loss 37.20946192741394
#  Val Accuracy = 97.5
# epoch 280
# 124.94757390022278 seconds
# loss 329.07393848896027
# Accuracy = 99.86077117919922
# 4.954364538192749 seconds
# val loss 37.23491644859314
#  Val Accuracy = 97.0
# epoch 281
# 124.99205684661865 seconds
# loss 329.07481503486633
# Accuracy = 99.86077117919922
# 4.957357883453369 seconds
# val loss 37.22396683692932
#  Val Accuracy = 97.0
# epoch 282
# 124.98353004455566 seconds
# loss 329.106880903244
# Accuracy = 99.86077117919922
# 4.9320783615112305 seconds
# val loss 37.3259881734848
#  Val Accuracy = 97.0
# epoch 283
# 125.11338305473328 seconds
# loss 329.0803349018097
# Accuracy = 99.86077117919922
# 4.98661208152771 seconds
# val loss 37.21866250038147
#  Val Accuracy = 97.5
# epoch 284
# 125.04852509498596 seconds
# loss 329.0760180950165
# Accuracy = 99.86077117919922
# 4.963149309158325 seconds
# val loss 37.16300189495087
#  Val Accuracy = 97.5
# epoch 285
# 124.99266409873962 seconds
# loss 329.0835237503052
# Accuracy = 99.86077117919922
# 4.973601341247559 seconds
# val loss 37.30157005786896
#  Val Accuracy = 97.0
# epoch 286
# 125.04041337966919 seconds
# loss 329.07559621334076
# Accuracy = 99.86077117919922
# 5.044041156768799 seconds
# val loss 37.204724073410034
#  Val Accuracy = 97.25
# epoch 287
# 124.87672638893127 seconds
# loss 329.07422482967377
# Accuracy = 99.86077117919922
# 4.949328660964966 seconds
# val loss 37.2834278345108
#  Val Accuracy = 97.25
# epoch 288
# 125.02992558479309 seconds
# loss 329.0786986351013
# Accuracy = 99.86077117919922
# 4.977216005325317 seconds
# val loss 37.324246287345886
#  Val Accuracy = 97.0
# epoch 289
# 124.97679018974304 seconds
# loss 329.08492600917816
# Accuracy = 99.86077117919922
# 4.978167295455933 seconds
# val loss 37.277904748916626
#  Val Accuracy = 96.75
# epoch 290
# 124.99369382858276 seconds
# loss 329.07655441761017
# Accuracy = 99.86077117919922
# 4.9567341804504395 seconds
# val loss 37.29430317878723
#  Val Accuracy = 97.25
# epoch 291
# 125.05105209350586 seconds
# loss 329.0767859220505
# Accuracy = 99.86077117919922
# 4.980478286743164 seconds
# val loss 37.18778598308563
#  Val Accuracy = 97.5
# epoch 292
# 125.03733849525452 seconds
# loss 329.0764299631119
# Accuracy = 99.86077117919922
# 4.97102427482605 seconds
# val loss 37.389097809791565
#  Val Accuracy = 96.75
# epoch 293
# 125.05406141281128 seconds
# loss 329.0753129720688
# Accuracy = 99.86077117919922
# 4.96365213394165 seconds
# val loss 37.535120248794556
#  Val Accuracy = 95.75
# epoch 294
# 124.94844007492065 seconds
# loss 329.07735085487366
# Accuracy = 99.86077117919922
# 4.958216190338135 seconds
# val loss 37.23466420173645
#  Val Accuracy = 97.5
# epoch 295
# 124.98982286453247 seconds
# loss 329.0761752128601
# Accuracy = 99.86077117919922
# 4.9863903522491455 seconds
# val loss 37.25865304470062
#  Val Accuracy = 97.0
# epoch 296
# 125.0221357345581 seconds
# loss 329.0745027065277
# Accuracy = 99.86077117919922
# 4.948103666305542 seconds
# val loss 37.32571220397949
#  Val Accuracy = 96.5
# epoch 297
# 125.0667953491211 seconds
# loss 329.07671070098877
# Accuracy = 99.86077117919922
# 4.986371994018555 seconds
# val loss 37.198554277420044
#  Val Accuracy = 97.5
# epoch 298
# 125.0196807384491 seconds
# loss 329.075227022171
# Accuracy = 99.86077117919922
# 4.954650640487671 seconds
# val loss 37.20391380786896
#  Val Accuracy = 97.25
# epoch 299
# 125.18606948852539 seconds
# loss 329.0844568014145
# Accuracy = 99.86077117919922
# 4.981971263885498 seconds
# val loss 37.214600801467896
#  Val Accuracy = 97.5
# epoch 300
# 125.12304282188416 seconds
# loss 329.09995210170746
# Accuracy = 99.86077117919922
# 4.946413993835449 seconds
# val loss 37.34839916229248
#  Val Accuracy = 97.0
# Finished Training
