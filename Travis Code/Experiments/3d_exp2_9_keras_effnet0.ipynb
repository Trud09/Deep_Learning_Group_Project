# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
root_dir = '/content/drive/MyDrive/Models_exp2.9'

# %%
import os
import multiprocessing
import numpy as np
import cv2
import time
import shutil

import torch

import keras
from tensorflow.keras.applications import EfficientNetB0

# %%
if torch.cuda.is_available():  
  dev = "cuda:0" 
else:  
  dev = "cpu"  

device = torch.device(dev)
print(device)
# Out:
# cuda:0

# %%
# !nvidia-smi
# Out:
# Fri Apr 30 14:53:17 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   37C    P0    26W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
#https://keras.io/examples/vision/image_classification_efficientnet_fine_tuning/
#efficient nets are a lot easier to work with in keras
from keras import layers

def build_model(num_classes, IMG_SIZE):
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))

    eff_model = EfficientNetB0(include_top=False, input_tensor=inputs, weights="imagenet")

    # Freeze the pretrained weights
    eff_model.trainable = False

    # Rebuild top
    x = layers.GlobalAveragePooling2D(name="avg_pool")(eff_model.output)
    x = layers.BatchNormalization()(x)

    # top_dropout_rate = 0.2
    # x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    outputs = layers.Dense(num_classes, activation="softmax", name="pred")(x)

    # Compile
    model = keras.Model(inputs, outputs, name="EfficientNet")
    optimizer = keras.optimizers.SGD(learning_rate=.001, momentum=0.9)
    model.compile(
        optimizer=optimizer, loss="categorical_crossentropy", metrics=["accuracy"]
    )
    return model

# %%
class Date_3d_Cached(torch.utils.data.Dataset):
    def __init__(self, x, y):
      self.x = torch.from_numpy(x)
      self.y = torch.from_numpy(y)
    
    def __len__(self):
      return self.x.shape[0]

    def __getitem__(self, idx):
      x = self.x[idx]
      return x, self.y[idx]

# %%
views = ['bottom', 'side_1', 'side_2', 'side_3', 'side_4', 'top', 'top_1', 'top_2', 'top_3', 'top_4', 'bot_1', 'bot_2', 'bot_3', 'bot_4']
x = np.load('/content/drive/MyDrive/Cache/x_compressed.npz')['arr_0']
y = np.load('/content/drive/MyDrive/Cache/y.npy')

# %%
reshaped_x = x.transpose([0, 1, 3, 4, 2])

# %%
one_hot_y = keras.utils.to_categorical(y, 10)

# %%
training_data = Date_3d_Cached(reshaped_x, one_hot_y)
#90/10 train val split
train_len = int(len(training_data) * .9)
val_len = len(training_data) - train_len

# %%
train_set, val_set = torch.utils.data.random_split(training_data, [train_len, val_len],torch.Generator().manual_seed(42))

# %%
print(os.cpu_count())
print(train_len)
print(val_len)
# Out:
# 4
# 3591
# 400

# %%
x, y = train_set[:]
x = x.numpy()
y = y.numpy()

# %%
val_x, val_y = val_set[:]
val_x = val_x.numpy()
val_y = val_y.numpy()

# %%
del train_set
del val_set

del training_data

# %%
del one_hot_y
del reshaped_x

# %%
#https://stackoverflow.com/questions/60567679/save-keras-model-weights-directly-to-bytes-memory
class Save_Best_Weights(keras.callbacks.Callback):   
  def __init__(self, min=True, metric='val_loss'):
      super(Save_Best_Weights, self).__init__()
      self.best = np.Inf
      self.metric = metric
      self.min = min
      if not min:
        self.best = self.best * - 1


  def on_epoch_end(self, epoch, logs=None):
      current_metric = logs.get(self.metric)
      if self.min:
        if np.less(current_metric, self.best):
            self.best = current_metric            
            self.best_weights = model.get_weights() 
            self.name = 'ep_' + str(epoch) + '_' + self.metric + "_" + str(self.best)
            print('saved new ' + self.metric)
      else:
        if np.greater(current_metric, self.best):
            self.best = current_metric            
            self.best_weights = model.get_weights() 
            self.name = 'ep_' + str(epoch) + '_' + self.metric + "_" + str(self.best)
            print('saved new ' + self.metric)

# %%
batch_size = 32
epochs = 100

if not os.path.exists(root_dir):
    os.makedirs(root_dir)


for idx, view in enumerate(views):
    this_dir = os.path.join(root_dir, view + '_' + str(idx))
    if not os.path.exists(this_dir):
      os.makedirs(this_dir)
    model = build_model(10, 224)
    print(view)
    loss_cp = Save_Best_Weights(
    )

    acc_cp = Save_Best_Weights(
        metric="val_accuracy",
        min=False
    )

    logger = keras.callbacks.CSVLogger(os.path.join(this_dir, 'logs.csv'))
      
    
    batch_x = x[:, idx, ...]
    batch_val_x = val_x[:, idx, ...]

    model.fit(batch_x, y, batch_size, epochs, callbacks=[loss_cp, acc_cp, logger], validation_data=(batch_val_x, val_y))


    #loss saving
    model.set_weights(loss_cp.best_weights)
    model.save(os.path.join(this_dir, loss_cp.name))

    #acc saving
    model.set_weights(acc_cp.best_weights)
    model.save(os.path.join(this_dir, acc_cp.name))
          

      

print('Finished Training')
# Out:
# bottom
# Epoch 1/100
# 113/113 [==============================] - 12s 53ms/step - loss: 1.8070 - accuracy: 0.4494 - val_loss: 1.0932 - val_accuracy: 0.7475
# saved new val_loss
# saved new val_accuracy
# Epoch 2/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.7565 - accuracy: 0.7489 - val_loss: 0.7412 - val_accuracy: 0.8250
# saved new val_loss
# saved new val_accuracy
# Epoch 3/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.6064 - accuracy: 0.8053 - val_loss: 0.5750 - val_accuracy: 0.8225
# saved new val_loss
# Epoch 4/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.5356 - accuracy: 0.8242 - val_loss: 0.5243 - val_accuracy: 0.8300
# saved new val_loss
# saved new val_accuracy
# Epoch 5/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.4887 - accuracy: 0.8414 - val_loss: 0.5028 - val_accuracy: 0.8300
# saved new val_loss
# Epoch 6/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.4338 - accuracy: 0.8533 - val_loss: 0.4863 - val_accuracy: 0.8475
# saved new val_loss
# saved new val_accuracy
# Epoch 7/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.4235 - accuracy: 0.8662 - val_loss: 0.4718 - val_accuracy: 0.8450
# saved new val_loss
# Epoch 8/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.4326 - accuracy: 0.8634 - val_loss: 0.4665 - val_accuracy: 0.8450
# saved new val_loss
# Epoch 9/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.4058 - accuracy: 0.8637 - val_loss: 0.4677 - val_accuracy: 0.8475
# Epoch 10/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.4001 - accuracy: 0.8693 - val_loss: 0.4546 - val_accuracy: 0.8525
# saved new val_loss
# saved new val_accuracy
# Epoch 11/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3648 - accuracy: 0.8782 - val_loss: 0.4561 - val_accuracy: 0.8600
# saved new val_accuracy
# Epoch 12/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3643 - accuracy: 0.8847 - val_loss: 0.4436 - val_accuracy: 0.8550
# saved new val_loss
# Epoch 13/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3547 - accuracy: 0.8836 - val_loss: 0.4567 - val_accuracy: 0.8575
# Epoch 14/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3094 - accuracy: 0.8999 - val_loss: 0.4498 - val_accuracy: 0.8550
# Epoch 15/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3180 - accuracy: 0.8896 - val_loss: 0.4506 - val_accuracy: 0.8625
# saved new val_accuracy
# Epoch 16/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3031 - accuracy: 0.9025 - val_loss: 0.4449 - val_accuracy: 0.8550
# Epoch 17/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3067 - accuracy: 0.9006 - val_loss: 0.4401 - val_accuracy: 0.8650
# saved new val_loss
# saved new val_accuracy
# Epoch 18/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2953 - accuracy: 0.9062 - val_loss: 0.4402 - val_accuracy: 0.8675
# saved new val_accuracy
# Epoch 19/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3136 - accuracy: 0.8962 - val_loss: 0.4394 - val_accuracy: 0.8600
# saved new val_loss
# Epoch 20/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3063 - accuracy: 0.9040 - val_loss: 0.4351 - val_accuracy: 0.8625
# saved new val_loss
# Epoch 21/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2961 - accuracy: 0.9037 - val_loss: 0.4358 - val_accuracy: 0.8700
# saved new val_accuracy
# Epoch 22/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2957 - accuracy: 0.9050 - val_loss: 0.4399 - val_accuracy: 0.8675
# Epoch 23/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2798 - accuracy: 0.9058 - val_loss: 0.4332 - val_accuracy: 0.8675
# saved new val_loss
# Epoch 24/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2568 - accuracy: 0.9208 - val_loss: 0.4409 - val_accuracy: 0.8675
# Epoch 25/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2525 - accuracy: 0.9244 - val_loss: 0.4417 - val_accuracy: 0.8650
# Epoch 26/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2884 - accuracy: 0.8996 - val_loss: 0.4388 - val_accuracy: 0.8700
# Epoch 27/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2664 - accuracy: 0.9169 - val_loss: 0.4397 - val_accuracy: 0.8625
# Epoch 28/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2636 - accuracy: 0.9159 - val_loss: 0.4371 - val_accuracy: 0.8625
# Epoch 29/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2670 - accuracy: 0.9201 - val_loss: 0.4437 - val_accuracy: 0.8675
# Epoch 30/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2677 - accuracy: 0.9148 - val_loss: 0.4400 - val_accuracy: 0.8675
# Epoch 31/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2514 - accuracy: 0.9195 - val_loss: 0.4405 - val_accuracy: 0.8675
# Epoch 32/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2341 - accuracy: 0.9306 - val_loss: 0.4389 - val_accuracy: 0.8600
# Epoch 33/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2519 - accuracy: 0.9228 - val_loss: 0.4397 - val_accuracy: 0.8700
# Epoch 34/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2486 - accuracy: 0.9239 - val_loss: 0.4472 - val_accuracy: 0.8600
# Epoch 35/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2338 - accuracy: 0.9284 - val_loss: 0.4480 - val_accuracy: 0.8600
# Epoch 36/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2453 - accuracy: 0.9214 - val_loss: 0.4450 - val_accuracy: 0.8700
# Epoch 37/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2216 - accuracy: 0.9286 - val_loss: 0.4416 - val_accuracy: 0.8625
# Epoch 38/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2191 - accuracy: 0.9331 - val_loss: 0.4476 - val_accuracy: 0.8725
# saved new val_accuracy
# Epoch 39/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2243 - accuracy: 0.9265 - val_loss: 0.4456 - val_accuracy: 0.8800
# saved new val_accuracy
# Epoch 40/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2320 - accuracy: 0.9242 - val_loss: 0.4477 - val_accuracy: 0.8675
# Epoch 41/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2064 - accuracy: 0.9415 - val_loss: 0.4492 - val_accuracy: 0.8675
# Epoch 42/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2121 - accuracy: 0.9327 - val_loss: 0.4415 - val_accuracy: 0.8725
# Epoch 43/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2286 - accuracy: 0.9247 - val_loss: 0.4480 - val_accuracy: 0.8625
# Epoch 44/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2194 - accuracy: 0.9317 - val_loss: 0.4441 - val_accuracy: 0.8675
# Epoch 45/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2087 - accuracy: 0.9350 - val_loss: 0.4509 - val_accuracy: 0.8700
# Epoch 46/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2052 - accuracy: 0.9374 - val_loss: 0.4437 - val_accuracy: 0.8625
# Epoch 47/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2081 - accuracy: 0.9302 - val_loss: 0.4514 - val_accuracy: 0.8675
# Epoch 48/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2128 - accuracy: 0.9329 - val_loss: 0.4416 - val_accuracy: 0.8725
# Epoch 49/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2123 - accuracy: 0.9304 - val_loss: 0.4478 - val_accuracy: 0.8700
# Epoch 50/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2265 - accuracy: 0.9195 - val_loss: 0.4468 - val_accuracy: 0.8700
# Epoch 51/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2145 - accuracy: 0.9253 - val_loss: 0.4456 - val_accuracy: 0.8700
# Epoch 52/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1935 - accuracy: 0.9334 - val_loss: 0.4448 - val_accuracy: 0.8750
# Epoch 53/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2108 - accuracy: 0.9290 - val_loss: 0.4486 - val_accuracy: 0.8725
# Epoch 54/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2025 - accuracy: 0.9368 - val_loss: 0.4480 - val_accuracy: 0.8700
# Epoch 55/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2000 - accuracy: 0.9380 - val_loss: 0.4523 - val_accuracy: 0.8675
# Epoch 56/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1745 - accuracy: 0.9449 - val_loss: 0.4467 - val_accuracy: 0.8700
# Epoch 57/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1923 - accuracy: 0.9399 - val_loss: 0.4521 - val_accuracy: 0.8750
# Epoch 58/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1835 - accuracy: 0.9449 - val_loss: 0.4493 - val_accuracy: 0.8675
# Epoch 59/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2012 - accuracy: 0.9396 - val_loss: 0.4467 - val_accuracy: 0.8675
# Epoch 60/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1919 - accuracy: 0.9422 - val_loss: 0.4513 - val_accuracy: 0.8725
# Epoch 61/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1696 - accuracy: 0.9528 - val_loss: 0.4464 - val_accuracy: 0.8775
# Epoch 62/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1830 - accuracy: 0.9427 - val_loss: 0.4474 - val_accuracy: 0.8775
# Epoch 63/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1968 - accuracy: 0.9366 - val_loss: 0.4522 - val_accuracy: 0.8725
# Epoch 64/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1915 - accuracy: 0.9399 - val_loss: 0.4461 - val_accuracy: 0.8700
# Epoch 65/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1840 - accuracy: 0.9413 - val_loss: 0.4494 - val_accuracy: 0.8725
# Epoch 66/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1937 - accuracy: 0.9329 - val_loss: 0.4532 - val_accuracy: 0.8700
# Epoch 67/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1810 - accuracy: 0.9400 - val_loss: 0.4539 - val_accuracy: 0.8700
# Epoch 68/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1707 - accuracy: 0.9466 - val_loss: 0.4516 - val_accuracy: 0.8825
# saved new val_accuracy
# Epoch 69/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1862 - accuracy: 0.9446 - val_loss: 0.4454 - val_accuracy: 0.8775
# Epoch 70/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1720 - accuracy: 0.9403 - val_loss: 0.4550 - val_accuracy: 0.8725
# Epoch 71/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1821 - accuracy: 0.9400 - val_loss: 0.4531 - val_accuracy: 0.8750
# Epoch 72/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1924 - accuracy: 0.9352 - val_loss: 0.4519 - val_accuracy: 0.8750
# Epoch 73/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1752 - accuracy: 0.9472 - val_loss: 0.4541 - val_accuracy: 0.8800
# Epoch 74/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1670 - accuracy: 0.9483 - val_loss: 0.4485 - val_accuracy: 0.8850
# saved new val_accuracy
# Epoch 75/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1776 - accuracy: 0.9454 - val_loss: 0.4574 - val_accuracy: 0.8750
# Epoch 76/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1765 - accuracy: 0.9443 - val_loss: 0.4566 - val_accuracy: 0.8725
# Epoch 77/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1701 - accuracy: 0.9505 - val_loss: 0.4580 - val_accuracy: 0.8750
# Epoch 78/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1765 - accuracy: 0.9506 - val_loss: 0.4603 - val_accuracy: 0.8700
# Epoch 79/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1714 - accuracy: 0.9498 - val_loss: 0.4547 - val_accuracy: 0.8875
# saved new val_accuracy
# Epoch 80/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1678 - accuracy: 0.9477 - val_loss: 0.4548 - val_accuracy: 0.8800
# Epoch 81/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1679 - accuracy: 0.9484 - val_loss: 0.4511 - val_accuracy: 0.8825
# Epoch 82/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1636 - accuracy: 0.9504 - val_loss: 0.4581 - val_accuracy: 0.8800
# Epoch 83/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1587 - accuracy: 0.9513 - val_loss: 0.4597 - val_accuracy: 0.8775
# Epoch 84/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1462 - accuracy: 0.9553 - val_loss: 0.4571 - val_accuracy: 0.8775
# Epoch 85/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1593 - accuracy: 0.9508 - val_loss: 0.4572 - val_accuracy: 0.8775
# Epoch 86/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1680 - accuracy: 0.9463 - val_loss: 0.4595 - val_accuracy: 0.8750
# Epoch 87/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1633 - accuracy: 0.9524 - val_loss: 0.4584 - val_accuracy: 0.8775
# Epoch 88/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1484 - accuracy: 0.9548 - val_loss: 0.4549 - val_accuracy: 0.8825
# Epoch 89/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1649 - accuracy: 0.9426 - val_loss: 0.4537 - val_accuracy: 0.8775
# Epoch 90/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1751 - accuracy: 0.9449 - val_loss: 0.4474 - val_accuracy: 0.8775
# Epoch 91/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1458 - accuracy: 0.9587 - val_loss: 0.4504 - val_accuracy: 0.8800
# Epoch 92/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1557 - accuracy: 0.9476 - val_loss: 0.4510 - val_accuracy: 0.8850
# Epoch 93/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1701 - accuracy: 0.9447 - val_loss: 0.4497 - val_accuracy: 0.8750
# Epoch 94/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1494 - accuracy: 0.9573 - val_loss: 0.4559 - val_accuracy: 0.8825
# Epoch 95/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1649 - accuracy: 0.9436 - val_loss: 0.4572 - val_accuracy: 0.8825
# Epoch 96/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1558 - accuracy: 0.9537 - val_loss: 0.4662 - val_accuracy: 0.8725
# Epoch 97/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1594 - accuracy: 0.9477 - val_loss: 0.4606 - val_accuracy: 0.8750
# Epoch 98/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1688 - accuracy: 0.9446 - val_loss: 0.4608 - val_accuracy: 0.8800
# Epoch 99/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1605 - accuracy: 0.9493 - val_loss: 0.4630 - val_accuracy: 0.8750
# Epoch 100/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1593 - accuracy: 0.9560 - val_loss: 0.4602 - val_accuracy: 0.8700
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.9/bottom_0/ep_22_val_loss_0.433198481798172/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.9/bottom_0/ep_78_val_accuracy_0.887499988079071/assets
# side_1
# Epoch 1/100
# 113/113 [==============================] - 11s 52ms/step - loss: 1.5707 - accuracy: 0.4903 - val_loss: 0.8379 - val_accuracy: 0.8250
# saved new val_loss
# saved new val_accuracy
# Epoch 2/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.4989 - accuracy: 0.8406 - val_loss: 0.5340 - val_accuracy: 0.8550
# saved new val_loss
# saved new val_accuracy
# Epoch 3/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.4448 - accuracy: 0.8483 - val_loss: 0.4180 - val_accuracy: 0.8650
# saved new val_loss
# saved new val_accuracy
# Epoch 4/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.3808 - accuracy: 0.8718 - val_loss: 0.3780 - val_accuracy: 0.8825
# saved new val_loss
# saved new val_accuracy
# Epoch 5/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3468 - accuracy: 0.8849 - val_loss: 0.3664 - val_accuracy: 0.8800
# saved new val_loss
# Epoch 6/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3050 - accuracy: 0.8988 - val_loss: 0.3488 - val_accuracy: 0.8850
# saved new val_loss
# saved new val_accuracy
# Epoch 7/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3026 - accuracy: 0.8930 - val_loss: 0.3426 - val_accuracy: 0.8850
# saved new val_loss
# Epoch 8/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2912 - accuracy: 0.9011 - val_loss: 0.3325 - val_accuracy: 0.8900
# saved new val_loss
# saved new val_accuracy
# Epoch 9/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2575 - accuracy: 0.9178 - val_loss: 0.3322 - val_accuracy: 0.8925
# saved new val_loss
# saved new val_accuracy
# Epoch 10/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2407 - accuracy: 0.9202 - val_loss: 0.3246 - val_accuracy: 0.8925
# saved new val_loss
# Epoch 11/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.2333 - accuracy: 0.9316 - val_loss: 0.3181 - val_accuracy: 0.9000
# saved new val_loss
# saved new val_accuracy
# Epoch 12/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.2310 - accuracy: 0.9226 - val_loss: 0.3161 - val_accuracy: 0.9025
# saved new val_loss
# saved new val_accuracy
# Epoch 13/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.2130 - accuracy: 0.9331 - val_loss: 0.3146 - val_accuracy: 0.9025
# saved new val_loss
# Epoch 14/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.2138 - accuracy: 0.9399 - val_loss: 0.3105 - val_accuracy: 0.9075
# saved new val_loss
# saved new val_accuracy
# Epoch 15/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.2252 - accuracy: 0.9268 - val_loss: 0.3104 - val_accuracy: 0.9050
# saved new val_loss
# Epoch 16/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.2055 - accuracy: 0.9386 - val_loss: 0.3134 - val_accuracy: 0.9075
# Epoch 17/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.2039 - accuracy: 0.9376 - val_loss: 0.3099 - val_accuracy: 0.9100
# saved new val_loss
# saved new val_accuracy
# Epoch 18/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.2133 - accuracy: 0.9361 - val_loss: 0.3150 - val_accuracy: 0.9050
# Epoch 19/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.2006 - accuracy: 0.9271 - val_loss: 0.3045 - val_accuracy: 0.9150
# saved new val_loss
# saved new val_accuracy
# Epoch 20/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1772 - accuracy: 0.9453 - val_loss: 0.3043 - val_accuracy: 0.9125
# saved new val_loss
# Epoch 21/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1778 - accuracy: 0.9467 - val_loss: 0.3008 - val_accuracy: 0.9100
# saved new val_loss
# Epoch 22/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1704 - accuracy: 0.9491 - val_loss: 0.3084 - val_accuracy: 0.9125
# Epoch 23/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1665 - accuracy: 0.9461 - val_loss: 0.3007 - val_accuracy: 0.9075
# saved new val_loss
# Epoch 24/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1725 - accuracy: 0.9491 - val_loss: 0.2993 - val_accuracy: 0.9150
# saved new val_loss
# Epoch 25/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1702 - accuracy: 0.9478 - val_loss: 0.2950 - val_accuracy: 0.9125
# saved new val_loss
# Epoch 26/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1608 - accuracy: 0.9544 - val_loss: 0.3028 - val_accuracy: 0.9125
# Epoch 27/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1595 - accuracy: 0.9490 - val_loss: 0.2941 - val_accuracy: 0.9200
# saved new val_loss
# saved new val_accuracy
# Epoch 28/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1746 - accuracy: 0.9435 - val_loss: 0.2987 - val_accuracy: 0.9125
# Epoch 29/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1468 - accuracy: 0.9579 - val_loss: 0.3030 - val_accuracy: 0.9150
# Epoch 30/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1522 - accuracy: 0.9565 - val_loss: 0.3026 - val_accuracy: 0.9150
# Epoch 31/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1517 - accuracy: 0.9520 - val_loss: 0.2998 - val_accuracy: 0.9175
# Epoch 32/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1378 - accuracy: 0.9626 - val_loss: 0.3013 - val_accuracy: 0.9125
# Epoch 33/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1318 - accuracy: 0.9628 - val_loss: 0.2984 - val_accuracy: 0.9225
# saved new val_accuracy
# Epoch 34/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1435 - accuracy: 0.9559 - val_loss: 0.2994 - val_accuracy: 0.9175
# Epoch 35/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1429 - accuracy: 0.9576 - val_loss: 0.2997 - val_accuracy: 0.9150
# Epoch 36/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1431 - accuracy: 0.9536 - val_loss: 0.2983 - val_accuracy: 0.9100
# Epoch 37/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1343 - accuracy: 0.9611 - val_loss: 0.3024 - val_accuracy: 0.9125
# Epoch 38/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1169 - accuracy: 0.9642 - val_loss: 0.2989 - val_accuracy: 0.9250
# saved new val_accuracy
# Epoch 39/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1171 - accuracy: 0.9724 - val_loss: 0.2989 - val_accuracy: 0.9175
# Epoch 40/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1328 - accuracy: 0.9630 - val_loss: 0.2997 - val_accuracy: 0.9225
# Epoch 41/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1410 - accuracy: 0.9592 - val_loss: 0.2963 - val_accuracy: 0.9175
# Epoch 42/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1297 - accuracy: 0.9596 - val_loss: 0.2962 - val_accuracy: 0.9200
# Epoch 43/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1286 - accuracy: 0.9652 - val_loss: 0.2961 - val_accuracy: 0.9175
# Epoch 44/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1320 - accuracy: 0.9617 - val_loss: 0.2979 - val_accuracy: 0.9250
# Epoch 45/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1369 - accuracy: 0.9612 - val_loss: 0.2991 - val_accuracy: 0.9200
# Epoch 46/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1251 - accuracy: 0.9609 - val_loss: 0.3018 - val_accuracy: 0.9175
# Epoch 47/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1204 - accuracy: 0.9637 - val_loss: 0.2978 - val_accuracy: 0.9225
# Epoch 48/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1184 - accuracy: 0.9647 - val_loss: 0.2988 - val_accuracy: 0.9250
# Epoch 49/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1272 - accuracy: 0.9617 - val_loss: 0.2999 - val_accuracy: 0.9275
# saved new val_accuracy
# Epoch 50/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1190 - accuracy: 0.9643 - val_loss: 0.2928 - val_accuracy: 0.9300
# saved new val_loss
# saved new val_accuracy
# Epoch 51/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1238 - accuracy: 0.9642 - val_loss: 0.2893 - val_accuracy: 0.9275
# saved new val_loss
# Epoch 52/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1068 - accuracy: 0.9694 - val_loss: 0.2920 - val_accuracy: 0.9225
# Epoch 53/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1219 - accuracy: 0.9657 - val_loss: 0.2912 - val_accuracy: 0.9300
# Epoch 54/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1169 - accuracy: 0.9666 - val_loss: 0.2946 - val_accuracy: 0.9250
# Epoch 55/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1046 - accuracy: 0.9742 - val_loss: 0.2954 - val_accuracy: 0.9300
# Epoch 56/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1125 - accuracy: 0.9680 - val_loss: 0.2978 - val_accuracy: 0.9275
# Epoch 57/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1084 - accuracy: 0.9653 - val_loss: 0.2980 - val_accuracy: 0.9250
# Epoch 58/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0963 - accuracy: 0.9728 - val_loss: 0.2955 - val_accuracy: 0.9225
# Epoch 59/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1022 - accuracy: 0.9701 - val_loss: 0.2980 - val_accuracy: 0.9225
# Epoch 60/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1052 - accuracy: 0.9682 - val_loss: 0.2921 - val_accuracy: 0.9275
# Epoch 61/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0994 - accuracy: 0.9749 - val_loss: 0.2963 - val_accuracy: 0.9250
# Epoch 62/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1099 - accuracy: 0.9644 - val_loss: 0.2964 - val_accuracy: 0.9250
# Epoch 63/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1016 - accuracy: 0.9716 - val_loss: 0.2985 - val_accuracy: 0.9300
# Epoch 64/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0949 - accuracy: 0.9773 - val_loss: 0.2979 - val_accuracy: 0.9300
# Epoch 65/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0988 - accuracy: 0.9731 - val_loss: 0.2957 - val_accuracy: 0.9250
# Epoch 66/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0951 - accuracy: 0.9732 - val_loss: 0.3010 - val_accuracy: 0.9225
# Epoch 67/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1061 - accuracy: 0.9684 - val_loss: 0.2992 - val_accuracy: 0.9250
# Epoch 68/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1017 - accuracy: 0.9739 - val_loss: 0.2972 - val_accuracy: 0.9200
# Epoch 69/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.1112 - accuracy: 0.9686 - val_loss: 0.2978 - val_accuracy: 0.9250
# Epoch 70/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1152 - accuracy: 0.9622 - val_loss: 0.2998 - val_accuracy: 0.9250
# Epoch 71/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0889 - accuracy: 0.9767 - val_loss: 0.3006 - val_accuracy: 0.9300
# Epoch 72/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0932 - accuracy: 0.9743 - val_loss: 0.3006 - val_accuracy: 0.9200
# Epoch 73/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0982 - accuracy: 0.9689 - val_loss: 0.2999 - val_accuracy: 0.9225
# Epoch 74/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0987 - accuracy: 0.9718 - val_loss: 0.2974 - val_accuracy: 0.9275
# Epoch 75/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1019 - accuracy: 0.9706 - val_loss: 0.2980 - val_accuracy: 0.9225
# Epoch 76/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1093 - accuracy: 0.9688 - val_loss: 0.2988 - val_accuracy: 0.9250
# Epoch 77/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0941 - accuracy: 0.9726 - val_loss: 0.3002 - val_accuracy: 0.9250
# Epoch 78/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0944 - accuracy: 0.9713 - val_loss: 0.2970 - val_accuracy: 0.9225
# Epoch 79/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0984 - accuracy: 0.9711 - val_loss: 0.2961 - val_accuracy: 0.9275
# Epoch 80/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0926 - accuracy: 0.9738 - val_loss: 0.2983 - val_accuracy: 0.9275
# Epoch 81/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0855 - accuracy: 0.9748 - val_loss: 0.2963 - val_accuracy: 0.9250
# Epoch 82/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0913 - accuracy: 0.9715 - val_loss: 0.3009 - val_accuracy: 0.9275
# Epoch 83/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0952 - accuracy: 0.9732 - val_loss: 0.2985 - val_accuracy: 0.9225
# Epoch 84/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0826 - accuracy: 0.9777 - val_loss: 0.3029 - val_accuracy: 0.9200
# Epoch 85/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0867 - accuracy: 0.9737 - val_loss: 0.3006 - val_accuracy: 0.9200
# Epoch 86/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0981 - accuracy: 0.9716 - val_loss: 0.2996 - val_accuracy: 0.9200
# Epoch 87/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0755 - accuracy: 0.9806 - val_loss: 0.3013 - val_accuracy: 0.9250
# Epoch 88/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0870 - accuracy: 0.9707 - val_loss: 0.3017 - val_accuracy: 0.9225
# Epoch 89/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0844 - accuracy: 0.9744 - val_loss: 0.3054 - val_accuracy: 0.9225
# Epoch 90/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0906 - accuracy: 0.9730 - val_loss: 0.3075 - val_accuracy: 0.9200
# Epoch 91/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0866 - accuracy: 0.9728 - val_loss: 0.3056 - val_accuracy: 0.9225
# Epoch 92/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0843 - accuracy: 0.9760 - val_loss: 0.3066 - val_accuracy: 0.9225
# Epoch 93/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0830 - accuracy: 0.9758 - val_loss: 0.3017 - val_accuracy: 0.9150
# Epoch 94/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0813 - accuracy: 0.9796 - val_loss: 0.3053 - val_accuracy: 0.9150
# Epoch 95/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0782 - accuracy: 0.9770 - val_loss: 0.3049 - val_accuracy: 0.9175
# Epoch 96/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0831 - accuracy: 0.9762 - val_loss: 0.3067 - val_accuracy: 0.9175
# Epoch 97/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0746 - accuracy: 0.9802 - val_loss: 0.3077 - val_accuracy: 0.9150
# Epoch 98/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0826 - accuracy: 0.9749 - val_loss: 0.3101 - val_accuracy: 0.9150
# Epoch 99/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0804 - accuracy: 0.9748 - val_loss: 0.3066 - val_accuracy: 0.9225
# Epoch 100/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0824 - accuracy: 0.9770 - val_loss: 0.3069 - val_accuracy: 0.9225
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.9/side_1_1/ep_50_val_loss_0.2893305718898773/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.9/side_1_1/ep_49_val_accuracy_0.9300000071525574/assets
# side_2
# Epoch 1/100
# 113/113 [==============================] - 10s 52ms/step - loss: 1.6560 - accuracy: 0.4948 - val_loss: 0.7681 - val_accuracy: 0.8525
# saved new val_loss
# saved new val_accuracy
# Epoch 2/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.4792 - accuracy: 0.8451 - val_loss: 0.4837 - val_accuracy: 0.8850
# saved new val_loss
# saved new val_accuracy
# Epoch 3/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3871 - accuracy: 0.8751 - val_loss: 0.3823 - val_accuracy: 0.8900
# saved new val_loss
# saved new val_accuracy
# Epoch 4/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3445 - accuracy: 0.8896 - val_loss: 0.3311 - val_accuracy: 0.9000
# saved new val_loss
# saved new val_accuracy
# Epoch 5/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2932 - accuracy: 0.9063 - val_loss: 0.3101 - val_accuracy: 0.8975
# saved new val_loss
# Epoch 6/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2753 - accuracy: 0.9110 - val_loss: 0.3017 - val_accuracy: 0.9050
# saved new val_loss
# saved new val_accuracy
# Epoch 7/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2508 - accuracy: 0.9131 - val_loss: 0.2994 - val_accuracy: 0.9075
# saved new val_loss
# saved new val_accuracy
# Epoch 8/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2487 - accuracy: 0.9196 - val_loss: 0.2872 - val_accuracy: 0.9150
# saved new val_loss
# saved new val_accuracy
# Epoch 9/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2307 - accuracy: 0.9203 - val_loss: 0.2770 - val_accuracy: 0.9150
# saved new val_loss
# Epoch 10/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2209 - accuracy: 0.9262 - val_loss: 0.2793 - val_accuracy: 0.9175
# saved new val_accuracy
# Epoch 11/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2209 - accuracy: 0.9267 - val_loss: 0.2693 - val_accuracy: 0.9150
# saved new val_loss
# Epoch 12/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1909 - accuracy: 0.9404 - val_loss: 0.2728 - val_accuracy: 0.9150
# Epoch 13/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1866 - accuracy: 0.9431 - val_loss: 0.2670 - val_accuracy: 0.9175
# saved new val_loss
# Epoch 14/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1971 - accuracy: 0.9396 - val_loss: 0.2620 - val_accuracy: 0.9175
# saved new val_loss
# Epoch 15/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1811 - accuracy: 0.9393 - val_loss: 0.2604 - val_accuracy: 0.9150
# saved new val_loss
# Epoch 16/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1886 - accuracy: 0.9368 - val_loss: 0.2557 - val_accuracy: 0.9200
# saved new val_loss
# saved new val_accuracy
# Epoch 17/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1800 - accuracy: 0.9442 - val_loss: 0.2544 - val_accuracy: 0.9225
# saved new val_loss
# saved new val_accuracy
# Epoch 18/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1596 - accuracy: 0.9480 - val_loss: 0.2603 - val_accuracy: 0.9200
# Epoch 19/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1628 - accuracy: 0.9451 - val_loss: 0.2588 - val_accuracy: 0.9200
# Epoch 20/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1647 - accuracy: 0.9505 - val_loss: 0.2542 - val_accuracy: 0.9125
# saved new val_loss
# Epoch 21/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1516 - accuracy: 0.9488 - val_loss: 0.2554 - val_accuracy: 0.9175
# Epoch 22/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1590 - accuracy: 0.9535 - val_loss: 0.2564 - val_accuracy: 0.9200
# Epoch 23/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1488 - accuracy: 0.9497 - val_loss: 0.2521 - val_accuracy: 0.9125
# saved new val_loss
# Epoch 24/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1534 - accuracy: 0.9536 - val_loss: 0.2536 - val_accuracy: 0.9175
# Epoch 25/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1383 - accuracy: 0.9613 - val_loss: 0.2488 - val_accuracy: 0.9225
# saved new val_loss
# Epoch 26/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1428 - accuracy: 0.9565 - val_loss: 0.2504 - val_accuracy: 0.9275
# saved new val_accuracy
# Epoch 27/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1383 - accuracy: 0.9607 - val_loss: 0.2519 - val_accuracy: 0.9225
# Epoch 28/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1313 - accuracy: 0.9634 - val_loss: 0.2489 - val_accuracy: 0.9225
# Epoch 29/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1308 - accuracy: 0.9643 - val_loss: 0.2475 - val_accuracy: 0.9250
# saved new val_loss
# Epoch 30/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1253 - accuracy: 0.9628 - val_loss: 0.2516 - val_accuracy: 0.9250
# Epoch 31/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1263 - accuracy: 0.9639 - val_loss: 0.2516 - val_accuracy: 0.9250
# Epoch 32/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1201 - accuracy: 0.9623 - val_loss: 0.2498 - val_accuracy: 0.9225
# Epoch 33/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1389 - accuracy: 0.9539 - val_loss: 0.2475 - val_accuracy: 0.9225
# Epoch 34/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1329 - accuracy: 0.9594 - val_loss: 0.2555 - val_accuracy: 0.9250
# Epoch 35/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1366 - accuracy: 0.9552 - val_loss: 0.2476 - val_accuracy: 0.9250
# Epoch 36/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1159 - accuracy: 0.9582 - val_loss: 0.2441 - val_accuracy: 0.9250
# saved new val_loss
# Epoch 37/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1146 - accuracy: 0.9700 - val_loss: 0.2488 - val_accuracy: 0.9275
# Epoch 38/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1098 - accuracy: 0.9642 - val_loss: 0.2499 - val_accuracy: 0.9225
# Epoch 39/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1109 - accuracy: 0.9663 - val_loss: 0.2415 - val_accuracy: 0.9225
# saved new val_loss
# Epoch 40/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1101 - accuracy: 0.9703 - val_loss: 0.2457 - val_accuracy: 0.9275
# Epoch 41/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1144 - accuracy: 0.9695 - val_loss: 0.2445 - val_accuracy: 0.9275
# Epoch 42/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1038 - accuracy: 0.9711 - val_loss: 0.2445 - val_accuracy: 0.9250
# Epoch 43/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1185 - accuracy: 0.9633 - val_loss: 0.2421 - val_accuracy: 0.9250
# Epoch 44/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1196 - accuracy: 0.9679 - val_loss: 0.2455 - val_accuracy: 0.9250
# Epoch 45/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1092 - accuracy: 0.9672 - val_loss: 0.2419 - val_accuracy: 0.9175
# Epoch 46/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1192 - accuracy: 0.9638 - val_loss: 0.2429 - val_accuracy: 0.9225
# Epoch 47/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0985 - accuracy: 0.9721 - val_loss: 0.2463 - val_accuracy: 0.9150
# Epoch 48/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1016 - accuracy: 0.9694 - val_loss: 0.2408 - val_accuracy: 0.9225
# saved new val_loss
# Epoch 49/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0851 - accuracy: 0.9780 - val_loss: 0.2415 - val_accuracy: 0.9275
# Epoch 50/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0939 - accuracy: 0.9786 - val_loss: 0.2459 - val_accuracy: 0.9225
# Epoch 51/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0968 - accuracy: 0.9713 - val_loss: 0.2427 - val_accuracy: 0.9250
# Epoch 52/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0904 - accuracy: 0.9716 - val_loss: 0.2441 - val_accuracy: 0.9250
# Epoch 53/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1088 - accuracy: 0.9667 - val_loss: 0.2460 - val_accuracy: 0.9175
# Epoch 54/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0914 - accuracy: 0.9738 - val_loss: 0.2428 - val_accuracy: 0.9175
# Epoch 55/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1011 - accuracy: 0.9704 - val_loss: 0.2431 - val_accuracy: 0.9150
# Epoch 56/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0840 - accuracy: 0.9792 - val_loss: 0.2490 - val_accuracy: 0.9175
# Epoch 57/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1127 - accuracy: 0.9631 - val_loss: 0.2496 - val_accuracy: 0.9150
# Epoch 58/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0851 - accuracy: 0.9727 - val_loss: 0.2494 - val_accuracy: 0.9225
# Epoch 59/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0892 - accuracy: 0.9758 - val_loss: 0.2429 - val_accuracy: 0.9150
# Epoch 60/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0928 - accuracy: 0.9743 - val_loss: 0.2477 - val_accuracy: 0.9175
# Epoch 61/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0879 - accuracy: 0.9751 - val_loss: 0.2454 - val_accuracy: 0.9175
# Epoch 62/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0941 - accuracy: 0.9710 - val_loss: 0.2448 - val_accuracy: 0.9150
# Epoch 63/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0836 - accuracy: 0.9754 - val_loss: 0.2444 - val_accuracy: 0.9150
# Epoch 64/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0787 - accuracy: 0.9786 - val_loss: 0.2452 - val_accuracy: 0.9200
# Epoch 65/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0890 - accuracy: 0.9748 - val_loss: 0.2381 - val_accuracy: 0.9150
# saved new val_loss
# Epoch 66/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0921 - accuracy: 0.9746 - val_loss: 0.2432 - val_accuracy: 0.9150
# Epoch 67/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1026 - accuracy: 0.9715 - val_loss: 0.2439 - val_accuracy: 0.9200
# Epoch 68/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0835 - accuracy: 0.9785 - val_loss: 0.2463 - val_accuracy: 0.9225
# Epoch 69/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0776 - accuracy: 0.9819 - val_loss: 0.2409 - val_accuracy: 0.9175
# Epoch 70/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0846 - accuracy: 0.9748 - val_loss: 0.2423 - val_accuracy: 0.9200
# Epoch 71/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0869 - accuracy: 0.9744 - val_loss: 0.2442 - val_accuracy: 0.9175
# Epoch 72/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0836 - accuracy: 0.9765 - val_loss: 0.2465 - val_accuracy: 0.9200
# Epoch 73/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0824 - accuracy: 0.9790 - val_loss: 0.2435 - val_accuracy: 0.9175
# Epoch 74/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0873 - accuracy: 0.9735 - val_loss: 0.2446 - val_accuracy: 0.9200
# Epoch 75/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0761 - accuracy: 0.9790 - val_loss: 0.2463 - val_accuracy: 0.9225
# Epoch 76/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0816 - accuracy: 0.9769 - val_loss: 0.2430 - val_accuracy: 0.9200
# Epoch 77/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0795 - accuracy: 0.9784 - val_loss: 0.2417 - val_accuracy: 0.9200
# Epoch 78/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0831 - accuracy: 0.9784 - val_loss: 0.2423 - val_accuracy: 0.9250
# Epoch 79/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0833 - accuracy: 0.9717 - val_loss: 0.2438 - val_accuracy: 0.9200
# Epoch 80/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0820 - accuracy: 0.9727 - val_loss: 0.2457 - val_accuracy: 0.9200
# Epoch 81/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0875 - accuracy: 0.9744 - val_loss: 0.2432 - val_accuracy: 0.9175
# Epoch 82/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0742 - accuracy: 0.9807 - val_loss: 0.2479 - val_accuracy: 0.9150
# Epoch 83/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0797 - accuracy: 0.9764 - val_loss: 0.2443 - val_accuracy: 0.9175
# Epoch 84/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0919 - accuracy: 0.9722 - val_loss: 0.2455 - val_accuracy: 0.9175
# Epoch 85/100
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0888 - accuracy: 0.9708 - val_loss: 0.2496 - val_accuracy: 0.9200
# Epoch 86/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0777 - accuracy: 0.9751 - val_loss: 0.2457 - val_accuracy: 0.9150
# Epoch 87/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0840 - accuracy: 0.9752 - val_loss: 0.2484 - val_accuracy: 0.9175
# Epoch 88/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0690 - accuracy: 0.9850 - val_loss: 0.2441 - val_accuracy: 0.9200
# Epoch 89/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0721 - accuracy: 0.9815 - val_loss: 0.2455 - val_accuracy: 0.9075
# Epoch 90/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0770 - accuracy: 0.9789 - val_loss: 0.2497 - val_accuracy: 0.9175
# Epoch 91/100
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0653 - accuracy: 0.9839 - val_loss: 0.2477 - val_accuracy: 0.9175
# Epoch 92/100
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0699 - accuracy: 0.9826 - val_loss: 0.2461 - val_accuracy: 0.9175
# Epoch 93/100
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0739 - accuracy: 0.9805 - val_loss: 0.2524 - val_accuracy: 0.9175
# Epoch 94/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0779 - accuracy: 0.9788 - val_loss: 0.2526 - val_accuracy: 0.9100
# Epoch 95/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0642 - accuracy: 0.9806 - val_loss: 0.2478 - val_accuracy: 0.9175
# Epoch 96/100
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0737 - accuracy: 0.9802 - val_loss: 0.2493 - val_accuracy: 0.9175
# Epoch 97/100
# 113/113 [==============================] - 5s 41ms/step - loss: 0.0621 - accuracy: 0.9856 - val_loss: 0.2479 - val_accuracy: 0.9175
# Epoch 98/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0734 - accuracy: 0.9789 - val_loss: 0.2466 - val_accuracy: 0.9150
# Epoch 99/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0641 - accuracy: 0.9842 - val_loss: 0.2501 - val_accuracy: 0.9125
# Epoch 100/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0711 - accuracy: 0.9774 - val_loss: 0.2522 - val_accuracy: 0.9175
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.9/side_2_2/ep_64_val_loss_0.23808467388153076/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.9/side_2_2/ep_25_val_accuracy_0.9275000095367432/assets
# side_3
# Epoch 1/100
# 113/113 [==============================] - 11s 52ms/step - loss: 1.5084 - accuracy: 0.5304 - val_loss: 0.6552 - val_accuracy: 0.8725
# saved new val_loss
# saved new val_accuracy
# Epoch 2/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3853 - accuracy: 0.8759 - val_loss: 0.3936 - val_accuracy: 0.9000
# saved new val_loss
# saved new val_accuracy
# Epoch 3/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.3308 - accuracy: 0.8941 - val_loss: 0.2969 - val_accuracy: 0.9150
# saved new val_loss
# saved new val_accuracy
# Epoch 4/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2628 - accuracy: 0.9088 - val_loss: 0.2643 - val_accuracy: 0.9275
# saved new val_loss
# saved new val_accuracy
# Epoch 5/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2355 - accuracy: 0.9236 - val_loss: 0.2312 - val_accuracy: 0.9300
# saved new val_loss
# saved new val_accuracy
# Epoch 6/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.2082 - accuracy: 0.9325 - val_loss: 0.2216 - val_accuracy: 0.9300
# saved new val_loss
# Epoch 7/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1834 - accuracy: 0.9394 - val_loss: 0.2143 - val_accuracy: 0.9325
# saved new val_loss
# saved new val_accuracy
# Epoch 8/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1851 - accuracy: 0.9358 - val_loss: 0.2056 - val_accuracy: 0.9375
# saved new val_loss
# saved new val_accuracy
# Epoch 9/100
# ...
# Epoch 100/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0530 - accuracy: 0.9870 - val_loss: 0.2697 - val_accuracy: 0.9250
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.9/bot_3_12/ep_53_val_loss_0.2625494599342346/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.9/bot_3_12/ep_96_val_accuracy_0.925000011920929/assets
# bot_4
# Epoch 1/100
# 113/113 [==============================] - 11s 53ms/step - loss: 1.7048 - accuracy: 0.4683 - val_loss: 0.8388 - val_accuracy: 0.8125
# saved new val_loss
# saved new val_accuracy
# Epoch 2/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.4930 - accuracy: 0.8460 - val_loss: 0.5192 - val_accuracy: 0.8775
# saved new val_loss
# saved new val_accuracy
# Epoch 3/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.3779 - accuracy: 0.8761 - val_loss: 0.3908 - val_accuracy: 0.8850
# saved new val_loss
# saved new val_accuracy
# Epoch 4/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.3540 - accuracy: 0.8863 - val_loss: 0.3316 - val_accuracy: 0.8900
# saved new val_loss
# saved new val_accuracy
# Epoch 5/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.2977 - accuracy: 0.9031 - val_loss: 0.3113 - val_accuracy: 0.9000
# saved new val_loss
# saved new val_accuracy
# Epoch 6/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.2771 - accuracy: 0.9157 - val_loss: 0.2938 - val_accuracy: 0.9025
# saved new val_loss
# saved new val_accuracy
# Epoch 7/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.2483 - accuracy: 0.9167 - val_loss: 0.2876 - val_accuracy: 0.9000
# saved new val_loss
# Epoch 8/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.2342 - accuracy: 0.9208 - val_loss: 0.2753 - val_accuracy: 0.9025
# saved new val_loss
# Epoch 9/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.2273 - accuracy: 0.9248 - val_loss: 0.2676 - val_accuracy: 0.9100
# saved new val_loss
# saved new val_accuracy
# Epoch 10/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.2072 - accuracy: 0.9361 - val_loss: 0.2649 - val_accuracy: 0.9150
# saved new val_loss
# saved new val_accuracy
# Epoch 11/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.2056 - accuracy: 0.9324 - val_loss: 0.2627 - val_accuracy: 0.9175
# saved new val_loss
# saved new val_accuracy
# Epoch 12/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.1778 - accuracy: 0.9430 - val_loss: 0.2642 - val_accuracy: 0.9050
# Epoch 13/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1959 - accuracy: 0.9317 - val_loss: 0.2594 - val_accuracy: 0.9225
# saved new val_loss
# saved new val_accuracy
# Epoch 14/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1699 - accuracy: 0.9496 - val_loss: 0.2496 - val_accuracy: 0.9225
# saved new val_loss
# Epoch 15/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1649 - accuracy: 0.9473 - val_loss: 0.2519 - val_accuracy: 0.9200
# Epoch 16/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1850 - accuracy: 0.9354 - val_loss: 0.2505 - val_accuracy: 0.9200
# Epoch 17/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1456 - accuracy: 0.9584 - val_loss: 0.2478 - val_accuracy: 0.9175
# saved new val_loss
# Epoch 18/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1674 - accuracy: 0.9516 - val_loss: 0.2394 - val_accuracy: 0.9225
# saved new val_loss
# Epoch 19/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1471 - accuracy: 0.9527 - val_loss: 0.2389 - val_accuracy: 0.9250
# saved new val_loss
# saved new val_accuracy
# Epoch 20/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1451 - accuracy: 0.9574 - val_loss: 0.2363 - val_accuracy: 0.9300
# saved new val_loss
# saved new val_accuracy
# Epoch 21/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1445 - accuracy: 0.9554 - val_loss: 0.2379 - val_accuracy: 0.9275
# Epoch 22/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1401 - accuracy: 0.9553 - val_loss: 0.2377 - val_accuracy: 0.9275
# Epoch 23/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1267 - accuracy: 0.9574 - val_loss: 0.2412 - val_accuracy: 0.9225
# Epoch 24/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1354 - accuracy: 0.9633 - val_loss: 0.2371 - val_accuracy: 0.9300
# Epoch 25/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1428 - accuracy: 0.9526 - val_loss: 0.2405 - val_accuracy: 0.9200
# Epoch 26/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1271 - accuracy: 0.9606 - val_loss: 0.2396 - val_accuracy: 0.9300
# Epoch 27/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1218 - accuracy: 0.9631 - val_loss: 0.2402 - val_accuracy: 0.9250
# Epoch 28/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1147 - accuracy: 0.9665 - val_loss: 0.2401 - val_accuracy: 0.9225
# Epoch 29/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1265 - accuracy: 0.9630 - val_loss: 0.2345 - val_accuracy: 0.9275
# saved new val_loss
# Epoch 30/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1182 - accuracy: 0.9689 - val_loss: 0.2361 - val_accuracy: 0.9275
# Epoch 31/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1300 - accuracy: 0.9586 - val_loss: 0.2351 - val_accuracy: 0.9200
# Epoch 32/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1163 - accuracy: 0.9633 - val_loss: 0.2329 - val_accuracy: 0.9250
# saved new val_loss
# Epoch 33/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1082 - accuracy: 0.9689 - val_loss: 0.2333 - val_accuracy: 0.9250
# Epoch 34/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1100 - accuracy: 0.9668 - val_loss: 0.2337 - val_accuracy: 0.9300
# Epoch 35/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1074 - accuracy: 0.9682 - val_loss: 0.2351 - val_accuracy: 0.9275
# Epoch 36/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1031 - accuracy: 0.9744 - val_loss: 0.2334 - val_accuracy: 0.9300
# Epoch 37/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1121 - accuracy: 0.9661 - val_loss: 0.2315 - val_accuracy: 0.9275
# saved new val_loss
# Epoch 38/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1046 - accuracy: 0.9760 - val_loss: 0.2312 - val_accuracy: 0.9275
# saved new val_loss
# Epoch 39/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.1053 - accuracy: 0.9721 - val_loss: 0.2283 - val_accuracy: 0.9275
# saved new val_loss
# Epoch 40/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0949 - accuracy: 0.9750 - val_loss: 0.2299 - val_accuracy: 0.9275
# Epoch 41/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0876 - accuracy: 0.9762 - val_loss: 0.2281 - val_accuracy: 0.9325
# saved new val_loss
# saved new val_accuracy
# Epoch 42/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0857 - accuracy: 0.9769 - val_loss: 0.2277 - val_accuracy: 0.9275
# saved new val_loss
# Epoch 43/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0845 - accuracy: 0.9796 - val_loss: 0.2300 - val_accuracy: 0.9300
# Epoch 44/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0980 - accuracy: 0.9702 - val_loss: 0.2330 - val_accuracy: 0.9300
# Epoch 45/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0897 - accuracy: 0.9756 - val_loss: 0.2295 - val_accuracy: 0.9275
# Epoch 46/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0867 - accuracy: 0.9736 - val_loss: 0.2281 - val_accuracy: 0.9300
# Epoch 47/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0855 - accuracy: 0.9756 - val_loss: 0.2285 - val_accuracy: 0.9300
# Epoch 48/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0862 - accuracy: 0.9759 - val_loss: 0.2298 - val_accuracy: 0.9325
# Epoch 49/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0794 - accuracy: 0.9778 - val_loss: 0.2309 - val_accuracy: 0.9275
# Epoch 50/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0803 - accuracy: 0.9795 - val_loss: 0.2342 - val_accuracy: 0.9300
# Epoch 51/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0826 - accuracy: 0.9802 - val_loss: 0.2340 - val_accuracy: 0.9300
# Epoch 52/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0917 - accuracy: 0.9713 - val_loss: 0.2277 - val_accuracy: 0.9300
# Epoch 53/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0849 - accuracy: 0.9762 - val_loss: 0.2284 - val_accuracy: 0.9300
# Epoch 54/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0779 - accuracy: 0.9812 - val_loss: 0.2266 - val_accuracy: 0.9325
# saved new val_loss
# Epoch 55/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0764 - accuracy: 0.9817 - val_loss: 0.2319 - val_accuracy: 0.9325
# Epoch 56/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0832 - accuracy: 0.9765 - val_loss: 0.2296 - val_accuracy: 0.9275
# Epoch 57/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0820 - accuracy: 0.9749 - val_loss: 0.2302 - val_accuracy: 0.9275
# Epoch 58/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0718 - accuracy: 0.9833 - val_loss: 0.2250 - val_accuracy: 0.9325
# saved new val_loss
# Epoch 59/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0760 - accuracy: 0.9796 - val_loss: 0.2296 - val_accuracy: 0.9350
# saved new val_accuracy
# Epoch 60/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0789 - accuracy: 0.9758 - val_loss: 0.2280 - val_accuracy: 0.9375
# saved new val_accuracy
# Epoch 61/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0724 - accuracy: 0.9801 - val_loss: 0.2282 - val_accuracy: 0.9350
# Epoch 62/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0754 - accuracy: 0.9832 - val_loss: 0.2275 - val_accuracy: 0.9300
# Epoch 63/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0785 - accuracy: 0.9787 - val_loss: 0.2305 - val_accuracy: 0.9275
# Epoch 64/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0823 - accuracy: 0.9772 - val_loss: 0.2299 - val_accuracy: 0.9325
# Epoch 65/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0713 - accuracy: 0.9816 - val_loss: 0.2296 - val_accuracy: 0.9275
# Epoch 66/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0750 - accuracy: 0.9805 - val_loss: 0.2305 - val_accuracy: 0.9275
# Epoch 67/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0721 - accuracy: 0.9824 - val_loss: 0.2318 - val_accuracy: 0.9300
# Epoch 68/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0740 - accuracy: 0.9754 - val_loss: 0.2316 - val_accuracy: 0.9350
# Epoch 69/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0625 - accuracy: 0.9846 - val_loss: 0.2304 - val_accuracy: 0.9300
# Epoch 70/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0768 - accuracy: 0.9746 - val_loss: 0.2317 - val_accuracy: 0.9300
# Epoch 71/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0712 - accuracy: 0.9839 - val_loss: 0.2330 - val_accuracy: 0.9250
# Epoch 72/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0707 - accuracy: 0.9804 - val_loss: 0.2325 - val_accuracy: 0.9275
# Epoch 73/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0704 - accuracy: 0.9840 - val_loss: 0.2349 - val_accuracy: 0.9250
# Epoch 74/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0685 - accuracy: 0.9819 - val_loss: 0.2318 - val_accuracy: 0.9250
# Epoch 75/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0692 - accuracy: 0.9834 - val_loss: 0.2336 - val_accuracy: 0.9275
# Epoch 76/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0687 - accuracy: 0.9844 - val_loss: 0.2363 - val_accuracy: 0.9225
# Epoch 77/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0689 - accuracy: 0.9826 - val_loss: 0.2340 - val_accuracy: 0.9300
# Epoch 78/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0617 - accuracy: 0.9844 - val_loss: 0.2309 - val_accuracy: 0.9325
# Epoch 79/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0736 - accuracy: 0.9784 - val_loss: 0.2320 - val_accuracy: 0.9325
# Epoch 80/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0641 - accuracy: 0.9813 - val_loss: 0.2329 - val_accuracy: 0.9300
# Epoch 81/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0702 - accuracy: 0.9794 - val_loss: 0.2335 - val_accuracy: 0.9325
# Epoch 82/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0668 - accuracy: 0.9850 - val_loss: 0.2372 - val_accuracy: 0.9350
# Epoch 83/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0610 - accuracy: 0.9834 - val_loss: 0.2342 - val_accuracy: 0.9325
# Epoch 84/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0605 - accuracy: 0.9872 - val_loss: 0.2315 - val_accuracy: 0.9300
# Epoch 85/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0631 - accuracy: 0.9860 - val_loss: 0.2326 - val_accuracy: 0.9350
# Epoch 86/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0636 - accuracy: 0.9859 - val_loss: 0.2336 - val_accuracy: 0.9350
# Epoch 87/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0600 - accuracy: 0.9846 - val_loss: 0.2340 - val_accuracy: 0.9300
# Epoch 88/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0655 - accuracy: 0.9841 - val_loss: 0.2320 - val_accuracy: 0.9325
# Epoch 89/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0667 - accuracy: 0.9810 - val_loss: 0.2298 - val_accuracy: 0.9325
# Epoch 90/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0560 - accuracy: 0.9870 - val_loss: 0.2334 - val_accuracy: 0.9325
# Epoch 91/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0667 - accuracy: 0.9825 - val_loss: 0.2336 - val_accuracy: 0.9325
# Epoch 92/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0656 - accuracy: 0.9813 - val_loss: 0.2334 - val_accuracy: 0.9325
# Epoch 93/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0529 - accuracy: 0.9896 - val_loss: 0.2339 - val_accuracy: 0.9275
# Epoch 94/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0562 - accuracy: 0.9874 - val_loss: 0.2325 - val_accuracy: 0.9300
# Epoch 95/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0515 - accuracy: 0.9868 - val_loss: 0.2324 - val_accuracy: 0.9325
# Epoch 96/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0581 - accuracy: 0.9858 - val_loss: 0.2314 - val_accuracy: 0.9275
# Epoch 97/100
# 113/113 [==============================] - 4s 39ms/step - loss: 0.0638 - accuracy: 0.9854 - val_loss: 0.2321 - val_accuracy: 0.9300
# Epoch 98/100
# 113/113 [==============================] - 5s 40ms/step - loss: 0.0526 - accuracy: 0.9871 - val_loss: 0.2327 - val_accuracy: 0.9300
# Epoch 99/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0647 - accuracy: 0.9800 - val_loss: 0.2316 - val_accuracy: 0.9350
# Epoch 100/100
# 113/113 [==============================] - 4s 40ms/step - loss: 0.0563 - accuracy: 0.9871 - val_loss: 0.2364 - val_accuracy: 0.9350
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.9/bot_4_13/ep_57_val_loss_0.2250451296567917/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Models_exp2.9/bot_4_13/ep_59_val_accuracy_0.9375/assets
# Finished Training

# %%
import pandas as pd
     
# dictionary of lists  
this_dict = {'training loss': training_loss_list, 'training acc': training_acc_list, 'val loss': val_loss_list, 'val acc':val_acc_list}  
       
df = pd.DataFrame(this_dict) 
    
# saving the dataframe 
df.to_csv(os.path.join(root_dir, 'logs.csv'))

# %%
print('saved csv')

# %%
print(inputs.shape)

# %%
cp = torch.load(os.path.join(root_dir, 'last.pt'))
model.load_state_dict(cp['state_dict'])
optimizer.load_state_dict(cp['optimizer'])
last_epoch_done = cp['epoch'] - 1

# %%
#continue training


if not os.path.exists(root_dir):
    os.makedirs(root_dir)


low_val_loss = 30000000
best_acc = -1
epoch = 0

val_loss_path = None
acc_path = None
#https://stackoverflow.com/questions/8078330/csv-writing-within-loop
import csv
with open(os.path.join(root_dir, 'logs2.csv'), 'w') as file_csv:
  writer=csv.writer(file_csv, delimiter=',',lineterminator='\n',)
  writer.writerow(['epoch', 'loss', 'acc', 'val_loss', 'val_acc'])


  for epoch in range(last_epoch_done, 101):
      row = [epoch]
      is_best = False
      running_loss = 0.0
      correct = 0
      total = 0

      model.train()

      t0 = time.time()
      for i, data in enumerate(training_loader):
          # get the inputs; data is a list of [inputs, labels]
          inputs, labels = data

          # for this_view in range(inputs.shape[1]):
          #   if np.random.randint(0, 4) == 0:
          #     inputs[:, this_view, ...] = 1.0

          inputs = inputs.to(device)
          labels = labels.to(device)

          # zero the parameter gradients
          optimizer.zero_grad()

          # forward + backward + optimize
          outputs = model(inputs)
          loss = criterion(outputs, labels)
          loss.backward()
          optimizer.step()

          # print statistics
          correct += (outputs.argmax(1) == labels).float().sum() #https://stackoverflow.com/questions/51503851/calculate-the-accuracy-every-epoch-in-pytorch
          total += labels.shape[0]
          running_loss += loss.item()

      print('epoch', epoch)
      
      print('{} seconds'.format(time.time() - t0))
      print('loss', running_loss)
      row.append(running_loss)
      running_loss = 0.0

      accuracy = 100 * correct / total
      print("Accuracy = {}".format(accuracy))
      row.append(torch.IntTensor.item(accuracy))
      correct = 0
      total= 0

      running_loss = 0.0
      correct = 0
      total = 0

      optimizer.zero_grad()
      model.eval()
      t0 = time.time()
      with torch.no_grad():
          for i, data in enumerate(val_loader):
              
              # get the inputs; data is a list of [inputs, labels]
              inputs, labels = data
              inputs = inputs.to(device)
              labels = labels.to(device)            


              # forward + backward + optimize
              outputs = model(inputs)
              loss = criterion(outputs, labels)

              correct += (outputs.argmax(1) == labels).float().sum() #https://stackoverflow.com/questions/51503851/calculate-the-accuracy-every-epoch-in-pytorch
              total += labels.shape[0]
              running_loss += loss.item()

      print('{} seconds'.format(time.time() - t0))
      print('val loss', running_loss)
      row.append(running_loss)
      

      accuracy = 100 * correct / total
      print(" Val Accuracy = {}".format(accuracy))
      row.append(torch.IntTensor.item(accuracy))

      model_name = 'ep_' + str(epoch) + '_loss_' + str(running_loss) + '_acc_' + str(accuracy) + '.pt'
      full_model_path = os.path.join(root_dir, model_name)
      checkpoint = {
          'epoch': epoch + 1,
          'state_dict': model.state_dict(),
          'optimizer': optimizer.state_dict()
      }
      if running_loss < low_val_loss:
        if val_loss_path and os.path.exists(val_loss_path):
          open(val_loss_path, 'w').close() #overwrite and make the file blank instead - ref: https://stackoverflow.com/a/4914288/3553367
          os.remove(val_loss_path)
        val_loss_path = full_model_path.replace('.pt', 'val_loss_best.pt')
        save_ckp(model, val_loss_path)
        low_val_loss = running_loss
        print('new low loss')

      if accuracy > best_acc:
        if acc_path and os.path.exists(acc_path):
          open(acc_path, 'w').close() #overwrite and make the file blank instead - ref: https://stackoverflow.com/a/4914288/3553367
          os.remove(acc_path)
        acc_path = full_model_path.replace('.pt', 'acc_best.pt')
        save_ckp(model, acc_path)
        best_acc = accuracy
        print('new best acc')
      full_model_path = os.path.join(root_dir, 'last.pt')
      save_ckp(checkpoint, full_model_path)
          

      

      correct = 0
      total= 0
      running_loss = 0.0
      writer.writerow(row)
  print('Finished Training')
